# %%
import os
import torch
import torchvision
import tarfile
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchvision.datasets.utils import download_url
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from torch.utils.data import random_split
from torchvision.utils import make_grid
import matplotlib
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import glob
import torch.optim as optim
import time

import cv2
# %matplotlib inline

# %%
# from google.colab import drive
# drive.mount('/content/drive',force_remount=True)

# %%
data_dir = 'EuroSAT/'
print(os.listdir(data_dir))
# Out:
# ['AnnualCrop', 'Forest', 'HerbaceousVegetation', 'Highway', 'Industrial', 'label_map.json', 'Pasture', 'PermanentCrop', 'Residential', 'River', 'SeaLake', 'test.csv', 'train.csv', 'validation.csv']

# %%
d = "cpu"
if torch.cuda.is_available():
    d = "cuda:0"
device = torch.device(d)

print("Device: {}".format(device))
# Out:
# Device: cuda:0

# %%
class CustomDataset(Dataset):
    def __init__(self,path,image_size):
        self.imgs_path = path
        file_list = glob.glob(self.imgs_path + "*")
        self.data = []
        for class_path in file_list:
            class_name = class_path.split("\\")[-1]
            for img_path in glob.glob(class_path + "/*.jpg"):
                self.data.append([img_path, class_name])
        self.class_map = {"AnnualCrop" : 0, "Forest": 1,"HerbaceousVegetation": 2,"Highway": 3,"Industrial":4,"Pasture":5,"PermanentCrop":6,"Residential":7,"River":8,"SeaLake":9}
        self.img_dim = image_size
    def __len__(self):
        return len(self.data)
    def __getitem__(self, idx):
        img_path, class_name = self.data[idx]
        img = cv2.imread(img_path)
        img = cv2.resize(img, self.img_dim)
        class_id = self.class_map[class_name]
        transform = transforms.Compose([transforms.ToTensor()])
        img_tensor = transform(img)
        mean, std, var = torch.mean(img_tensor), torch.std(img_tensor), torch.var(img_tensor)
        img_tensor = (img_tensor-mean)/std
        class_id = torch.tensor([class_id])
        return img_tensor, class_id

# %%
from torch.utils.data.sampler import SubsetRandomSampler

def load_data(path, test_split, val_split, batch_size, input_size, shuffle_dataset=True,random_seed=42):
    dataset = CustomDataset(path,input_size)	
    # Creating data indices for training and test splits:
    dataset_size = len(dataset)
    train_test_indices = list(range(dataset_size))
    test_split = int(np.floor(test_split * dataset_size))
    if shuffle_dataset :
        np.random.seed(random_seed)
        np.random.shuffle(train_test_indices)
    train_indices, test_indices = train_test_indices[test_split:], train_test_indices[:test_split]


   # Creating data indices for training and validation splits:
   
    train_data_size=len(train_indices)
    train_val_indices = list(range(train_data_size))
    val_split = int(np.floor(val_split * train_data_size))
    if shuffle_dataset :
        np.random.seed(random_seed)
        np.random.shuffle(train_val_indices)
    train_indices, val_indices = train_val_indices[val_split:], train_val_indices[:val_split]



    # Creating PT data samplers and loaders:
    train_sampler = SubsetRandomSampler(train_indices)
    test_sampler = SubsetRandomSampler(test_indices)
    val_sampler = SubsetRandomSampler(val_indices)

    data_loader_train = torch.utils.data.DataLoader(dataset, batch_size=batch_size, 
                                              sampler=train_sampler)
    data_loader_test = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                                    sampler=test_sampler)

    data_loader_val = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                                    sampler=val_sampler)


   
    print(len(data_loader_train),len(data_loader_test),len(data_loader_val))
    
    return data_loader_train, data_loader_test, data_loader_val

# %%
data_loader_train, data_loader_test, data_loader_val=load_data(data_dir,.2,.2,32,(64,64))
# Out:
# 540 169 135

# %%
def plot_data_loader(data_loader, gridDims):
    
    fig, axes = plt.subplots(nrows=gridDims[0], ncols=gridDims[1], figsize=(5,5))
    dataiter = iter(data_loader)
    for i in range(gridDims[0]):
        for j in range(gridDims[1]):
            images, _ = next(dataiter)
            axes[i, j].imshow(np.transpose(images[0].numpy(), (1, 2, 0)))

# %%
plot_data_loader(data_loader_test,[2,2])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
model = torch.hub.load('pytorch/vision:v0.10.0', 'resnet18', weights=None)
# Out:
# Using cache found in C:\Users\solan/.cache\torch\hub\pytorch_vision_v0.10.0

# %%
optimizer = optim.Adam(model.parameters(),lr=0.001);
criterion = nn.CrossEntropyLoss()

# %%
model.to(device)

num_epochs = 20
total_steps = len(data_loader_train)
t1 = time.time()
accuracies = []
losses = []
accuracies_v = []
losses_v = []

for epoch in range(num_epochs):
    ti = 0;
    total_correct = 0;
    tl = 0.0
    for i, data in enumerate(data_loader_train):
        images, labels = data[0].to(device), data[1].to(device)
        labels=torch.flatten(labels)
        outputs = model(images)
        loss = criterion(outputs, labels)
        tl+=loss.item()
        # Backprop and optimisation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Train accuracy
        total = labels.size(0)
        ti+=total
        _,predicted = torch.max(outputs.data, 1)
        correct = (predicted == labels).sum().item()
        total_correct+= (predicted == labels).sum()

        if (i + 1) % 100 == 0:
            print('Epoch [{}/{}], Step [{}/{}], Train Loss: {:.4f}, Train Accuracy: {:.2f}%'
                  .format(epoch + 1, num_epochs, i + 1, total_steps, 
                          loss.item(),
                      (correct / total) * 100))
    # validation 
    total_correct_v = 0.0
    ti_v = 0
    tl_v = 0.0
    for _, data_v in enumerate(data_loader_val):
        images_v, labels_v = data_v[0].to(device), data_v[1].to(device)
        labels_v=torch.flatten(labels_v)
        outputs_v = model(images_v)
        loss_v = criterion(outputs_v,labels_v)
#         tl_v+=loss_v.item()
        valid_loss = loss_v.item() * images_v.size(0)
        tl_v+=valid_loss
        # Validation accuracy
        total_v = labels_v.size(0)
        ti_v+=total_v
        _,predicted_v = torch.max(outputs_v.data, 1)
        correct_v = (predicted_v == labels_v).sum().item() 
        total_correct_v+= (predicted_v == labels_v).sum() 
    print('Epoch [{}/{}], Validation Loss: {:.4f}, Validation Accuracy: {:.2f}%'.format(epoch + 1, num_epochs, float(tl_v)/ti_v, total_correct_v / ti_v*100.0))
    accuracies_v.append(total_correct_v / ti_v*100.0)    
    losses_v.append(float(tl_v)/ti_v)  
    accuracies.append(total_correct/ti*100.0)
    losses.append(float(tl)/ti)
           
print("######## Training Finished in {} seconds ###########".format(time.time()-t1))
# Out:
# Epoch [1/20], Step [100/540], Train Loss: 1.5998, Train Accuracy: 46.88%
# Epoch [1/20], Step [200/540], Train Loss: 0.7928, Train Accuracy: 65.62%
# Epoch [1/20], Step [300/540], Train Loss: 0.9179, Train Accuracy: 65.62%
# Epoch [1/20], Step [400/540], Train Loss: 0.6248, Train Accuracy: 71.88%
# Epoch [1/20], Step [500/540], Train Loss: 0.5367, Train Accuracy: 84.38%
# Epoch [1/20], Validation Loss: 0.7591, Validation Accuracy: 75.09%
# Epoch [2/20], Step [100/540], Train Loss: 0.6139, Train Accuracy: 75.00%
# Epoch [2/20], Step [200/540], Train Loss: 0.7739, Train Accuracy: 78.12%
# Epoch [2/20], Step [300/540], Train Loss: 0.4974, Train Accuracy: 81.25%
# Epoch [2/20], Step [400/540], Train Loss: 0.3855, Train Accuracy: 81.25%
# Epoch [2/20], Step [500/540], Train Loss: 0.6499, Train Accuracy: 78.12%
# Epoch [2/20], Validation Loss: 0.5563, Validation Accuracy: 81.39%
# Epoch [3/20], Step [100/540], Train Loss: 0.4341, Train Accuracy: 87.50%
# Epoch [3/20], Step [200/540], Train Loss: 0.4709, Train Accuracy: 84.38%
# Epoch [3/20], Step [300/540], Train Loss: 0.3985, Train Accuracy: 90.62%
# Epoch [3/20], Step [400/540], Train Loss: 0.4121, Train Accuracy: 87.50%
# Epoch [3/20], Step [500/540], Train Loss: 0.3131, Train Accuracy: 81.25%
# Epoch [3/20], Validation Loss: 0.5212, Validation Accuracy: 82.50%
# Epoch [4/20], Step [100/540], Train Loss: 0.3693, Train Accuracy: 90.62%
# Epoch [4/20], Step [200/540], Train Loss: 0.1427, Train Accuracy: 100.00%
# Epoch [4/20], Step [300/540], Train Loss: 0.1856, Train Accuracy: 96.88%
# Epoch [4/20], Step [400/540], Train Loss: 0.5058, Train Accuracy: 78.12%
# Epoch [4/20], Step [500/540], Train Loss: 0.5985, Train Accuracy: 81.25%
# Epoch [4/20], Validation Loss: 0.3951, Validation Accuracy: 86.55%
# Epoch [5/20], Step [100/540], Train Loss: 0.5898, Train Accuracy: 81.25%
# Epoch [5/20], Step [200/540], Train Loss: 0.3716, Train Accuracy: 87.50%
# Epoch [5/20], Step [300/540], Train Loss: 0.2298, Train Accuracy: 90.62%
# Epoch [5/20], Step [400/540], Train Loss: 0.5081, Train Accuracy: 78.12%
# Epoch [5/20], Step [500/540], Train Loss: 0.1224, Train Accuracy: 96.88%
# Epoch [5/20], Validation Loss: 0.3774, Validation Accuracy: 87.31%
# Epoch [6/20], Step [100/540], Train Loss: 0.1559, Train Accuracy: 93.75%
# Epoch [6/20], Step [200/540], Train Loss: 0.0967, Train Accuracy: 93.75%
# Epoch [6/20], Step [300/540], Train Loss: 0.1798, Train Accuracy: 93.75%
# Epoch [6/20], Step [400/540], Train Loss: 0.4489, Train Accuracy: 87.50%
# Epoch [6/20], Step [500/540], Train Loss: 0.1241, Train Accuracy: 96.88%
# Epoch [6/20], Validation Loss: 0.3512, Validation Accuracy: 88.77%
# Epoch [7/20], Step [100/540], Train Loss: 0.3493, Train Accuracy: 84.38%
# Epoch [7/20], Step [200/540], Train Loss: 0.2754, Train Accuracy: 87.50%
# Epoch [7/20], Step [300/540], Train Loss: 0.3927, Train Accuracy: 90.62%
# Epoch [7/20], Step [400/540], Train Loss: 0.1463, Train Accuracy: 100.00%
# Epoch [7/20], Step [500/540], Train Loss: 0.2762, Train Accuracy: 90.62%
# Epoch [7/20], Validation Loss: 0.3034, Validation Accuracy: 89.61%
# Epoch [8/20], Step [100/540], Train Loss: 0.1213, Train Accuracy: 96.88%
# Epoch [8/20], Step [200/540], Train Loss: 0.2023, Train Accuracy: 96.88%
# Epoch [8/20], Step [300/540], Train Loss: 0.1207, Train Accuracy: 93.75%
# Epoch [8/20], Step [400/540], Train Loss: 0.2380, Train Accuracy: 93.75%
# Epoch [8/20], Step [500/540], Train Loss: 0.2877, Train Accuracy: 93.75%
# Epoch [8/20], Validation Loss: 0.3354, Validation Accuracy: 89.79%
# Epoch [9/20], Step [100/540], Train Loss: 0.7978, Train Accuracy: 78.12%
# Epoch [9/20], Step [200/540], Train Loss: 0.2451, Train Accuracy: 93.75%
# Epoch [9/20], Step [300/540], Train Loss: 0.1596, Train Accuracy: 93.75%
# Epoch [9/20], Step [400/540], Train Loss: 0.1558, Train Accuracy: 93.75%
# Epoch [9/20], Step [500/540], Train Loss: 0.1037, Train Accuracy: 96.88%
# Epoch [9/20], Validation Loss: 0.2925, Validation Accuracy: 90.90%
# Epoch [10/20], Step [100/540], Train Loss: 0.0632, Train Accuracy: 96.88%
# Epoch [10/20], Step [200/540], Train Loss: 0.0618, Train Accuracy: 100.00%
# Epoch [10/20], Step [300/540], Train Loss: 0.2148, Train Accuracy: 90.62%
# Epoch [10/20], Step [400/540], Train Loss: 0.1102, Train Accuracy: 93.75%
# Epoch [10/20], Step [500/540], Train Loss: 0.1044, Train Accuracy: 96.88%
# Epoch [10/20], Validation Loss: 0.4586, Validation Accuracy: 87.01%
# Epoch [11/20], Step [100/540], Train Loss: 0.2019, Train Accuracy: 93.75%
# Epoch [11/20], Step [200/540], Train Loss: 0.0477, Train Accuracy: 100.00%
# Epoch [11/20], Step [300/540], Train Loss: 0.0544, Train Accuracy: 96.88%
# Epoch [11/20], Step [400/540], Train Loss: 0.2131, Train Accuracy: 87.50%
# Epoch [11/20], Step [500/540], Train Loss: 0.0126, Train Accuracy: 100.00%
# Epoch [11/20], Validation Loss: 0.3923, Validation Accuracy: 88.77%
# Epoch [12/20], Step [100/540], Train Loss: 0.0146, Train Accuracy: 100.00%
# Epoch [12/20], Step [200/540], Train Loss: 0.3180, Train Accuracy: 93.75%
# Epoch [12/20], Step [300/540], Train Loss: 0.0305, Train Accuracy: 100.00%
# Epoch [12/20], Step [400/540], Train Loss: 0.1001, Train Accuracy: 96.88%
# Epoch [12/20], Step [500/540], Train Loss: 0.1213, Train Accuracy: 90.62%
# Epoch [12/20], Validation Loss: 0.3309, Validation Accuracy: 90.32%
# Epoch [13/20], Step [100/540], Train Loss: 0.1196, Train Accuracy: 96.88%
# Epoch [13/20], Step [200/540], Train Loss: 0.0070, Train Accuracy: 100.00%
# Epoch [13/20], Step [300/540], Train Loss: 0.0486, Train Accuracy: 96.88%
# Epoch [13/20], Step [400/540], Train Loss: 0.5603, Train Accuracy: 84.38%
# Epoch [13/20], Step [500/540], Train Loss: 0.0538, Train Accuracy: 96.88%
# Epoch [13/20], Validation Loss: 0.3610, Validation Accuracy: 90.16%
# Epoch [14/20], Step [100/540], Train Loss: 0.0251, Train Accuracy: 100.00%
# Epoch [14/20], Step [200/540], Train Loss: 0.0103, Train Accuracy: 100.00%
# Epoch [14/20], Step [300/540], Train Loss: 0.0799, Train Accuracy: 96.88%
# Epoch [14/20], Step [400/540], Train Loss: 0.2841, Train Accuracy: 93.75%
# Epoch [14/20], Step [500/540], Train Loss: 0.0245, Train Accuracy: 100.00%
# Epoch [14/20], Validation Loss: 0.3820, Validation Accuracy: 89.93%
# Epoch [15/20], Step [100/540], Train Loss: 0.0209, Train Accuracy: 100.00%
# Epoch [15/20], Step [200/540], Train Loss: 0.0315, Train Accuracy: 100.00%
# Epoch [15/20], Step [300/540], Train Loss: 0.0789, Train Accuracy: 96.88%
# Epoch [15/20], Step [400/540], Train Loss: 0.1703, Train Accuracy: 93.75%
# Epoch [15/20], Step [500/540], Train Loss: 0.0702, Train Accuracy: 96.88%
# Epoch [15/20], Validation Loss: 0.3605, Validation Accuracy: 90.58%
# Epoch [16/20], Step [100/540], Train Loss: 0.0016, Train Accuracy: 100.00%
# Epoch [16/20], Step [200/540], Train Loss: 0.0075, Train Accuracy: 100.00%
# Epoch [16/20], Step [300/540], Train Loss: 0.0728, Train Accuracy: 93.75%
# Epoch [16/20], Step [400/540], Train Loss: 0.1324, Train Accuracy: 93.75%
# Epoch [16/20], Step [500/540], Train Loss: 0.0257, Train Accuracy: 100.00%
# Epoch [16/20], Validation Loss: 0.3904, Validation Accuracy: 89.93%
# Epoch [17/20], Step [100/540], Train Loss: 0.0266, Train Accuracy: 100.00%
# Epoch [17/20], Step [200/540], Train Loss: 0.0094, Train Accuracy: 100.00%
# Epoch [17/20], Step [300/540], Train Loss: 0.0137, Train Accuracy: 100.00%
# Epoch [17/20], Step [400/540], Train Loss: 0.0377, Train Accuracy: 96.88%
# Epoch [17/20], Step [500/540], Train Loss: 0.0024, Train Accuracy: 100.00%
# Epoch [17/20], Validation Loss: 0.3639, Validation Accuracy: 90.42%
# Epoch [18/20], Step [100/540], Train Loss: 0.0206, Train Accuracy: 100.00%
# Epoch [18/20], Step [200/540], Train Loss: 0.0143, Train Accuracy: 100.00%
# Epoch [18/20], Step [300/540], Train Loss: 0.0165, Train Accuracy: 100.00%
# Epoch [18/20], Step [400/540], Train Loss: 0.1011, Train Accuracy: 93.75%
# Epoch [18/20], Step [500/540], Train Loss: 0.0141, Train Accuracy: 100.00%
# Epoch [18/20], Validation Loss: 0.4089, Validation Accuracy: 90.30%
# Epoch [19/20], Step [100/540], Train Loss: 0.1170, Train Accuracy: 96.88%
# Epoch [19/20], Step [200/540], Train Loss: 0.0069, Train Accuracy: 100.00%
# Epoch [19/20], Step [300/540], Train Loss: 0.0737, Train Accuracy: 93.75%
# Epoch [19/20], Step [400/540], Train Loss: 0.1813, Train Accuracy: 90.62%
# Epoch [19/20], Step [500/540], Train Loss: 0.0642, Train Accuracy: 100.00%
# Epoch [19/20], Validation Loss: 0.4122, Validation Accuracy: 90.12%
# Epoch [20/20], Step [100/540], Train Loss: 0.0188, Train Accuracy: 100.00%
# Epoch [20/20], Step [200/540], Train Loss: 0.0654, Train Accuracy: 96.88%
# Epoch [20/20], Step [300/540], Train Loss: 0.0036, Train Accuracy: 100.00%
# Epoch [20/20], Step [400/540], Train Loss: 0.0224, Train Accuracy: 100.00%
# Epoch [20/20], Step [500/540], Train Loss: 0.0220, Train Accuracy: 100.00%
# Epoch [20/20], Validation Loss: 0.4292, Validation Accuracy: 89.56%
# ######## Training Finished in 1314.5678713321686 seconds ###########

# %%
model.eval() 
with torch.no_grad(): 
 correct = 0
 total = 0
 for data in data_loader_test:
  images, labels = data[0].to(device), data[1].to(device)
  labels=torch.flatten(labels)
  outputs = model(images)
  _, predicted = torch.max(outputs.data, 1)
  total += labels.size(0)
  correct += (predicted == labels).sum().item()
print('Test Accuracy of the model on the {} test images: {} %'
  .format(total, (correct / total) * 100))
# Out:
# Test Accuracy of the model on the 5400 test images: 78.29629629629629 %

# %%
acc_list = [i.item() for i in accuracies]

# %%
plt.figure()
plt.xlabel('epochs')
plt.ylabel('Accuracy')
plt.title('Train Accuracy plot')
plt.plot(range(1,num_epochs+1),acc_list)
plt.legend(['Accuracy'])

# %%
plt.figure()
plt.xlabel('epochs')
plt.ylabel('Loss')
plt.title('Train Loss plot')
plt.plot(range(1,num_epochs+1),losses,'g')
plt.legend(['Loss'])

# %%
acc_list_v = [i.item() for i in accuracies_v]

# %%
plt.figure()
plt.xlabel('epochs')
plt.ylabel('Accuracy')
plt.title('Validation Accuracy plot')
plt.plot(range(1,num_epochs+1),acc_list_v)
plt.legend(['Accuracy'])

# %%
plt.figure()
plt.xlabel('epochs')
plt.ylabel('Loss')
plt.title('Validation Loss plot')
plt.plot(range(1,num_epochs+1),losses,'g')
plt.legend(['Loss'])

# %%
plt.figure()
plt.xlabel('epochs')
plt.ylabel('Loss')
plt.title('Validation Loss plot')
plt.plot(range(1,num_epochs+1),losses,'g')
plt.legend(['Loss'])
