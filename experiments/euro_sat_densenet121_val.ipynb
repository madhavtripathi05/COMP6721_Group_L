# %%
import os
import torch
import torchvision
import tarfile
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchvision.datasets.utils import download_url
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from torch.utils.data import random_split
from torchvision.utils import make_grid
import matplotlib
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import glob
import torch.optim as optim
import time

import cv2
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
data_dir = 'drive/MyDrive/AI_DATASET/EuroSAT/EuroSAT/'
print(os.listdir(data_dir))
# Out:
# ['Forest', 'HerbaceousVegetation', 'Highway', 'Industrial', 'Pasture', 'PermanentCrop', 'Residential', 'River', 'SeaLake', 'AnnualCrop']

# %%
d = "cpu"
if torch.cuda.is_available():
    d = "cuda:0"
device = torch.device(d)

print("Device: {}".format(device))
# Out:
# Device: cuda:0

# %%
class CustomDataset(Dataset):
    def __init__(self,path,image_size):
        self.imgs_path = path
        file_list = glob.glob(self.imgs_path + "*")
        self.data = []
        for class_path in file_list:
            class_name = class_path.split("/")[-1]
            for img_path in glob.glob(class_path + "/*.jpg"):
                self.data.append([img_path, class_name])
        self.class_map = {"AnnualCrop" : 0, "Forest": 1,"HerbaceousVegetation": 2,"Highway": 3,"Industrial":4,"Pasture":5,"PermanentCrop":6,"Residential":7,"River":8,"SeaLake":9}
        self.img_dim = image_size
    def __len__(self):
        return len(self.data)
    def __getitem__(self, idx):
        img_path, class_name = self.data[idx]
        img = cv2.imread(img_path)
        img = cv2.resize(img, self.img_dim)
        class_id = self.class_map[class_name]
        transform = transforms.Compose([transforms.ToTensor()])
        img_tensor = transform(img)
        mean, std, var = torch.mean(img_tensor), torch.std(img_tensor), torch.var(img_tensor)
        img_tensor = (img_tensor-mean)/std
        class_id = torch.tensor([class_id])
        return img_tensor, class_id

# %%
from torch.utils.data.sampler import SubsetRandomSampler

def load_data(path, test_split, val_split, batch_size, input_size, shuffle_dataset=True,random_seed=42):
    dataset = CustomDataset(path,input_size)	
    # Creating data indices for training and test splits:
    dataset_size = len(dataset)
    train_test_indices = list(range(dataset_size))
    test_split = int(np.floor(test_split * dataset_size))
    if shuffle_dataset :
        np.random.seed(random_seed)
        np.random.shuffle(train_test_indices)
    train_indices, test_indices = train_test_indices[test_split:], train_test_indices[:test_split]


   # Creating data indices for training and validation splits:
   
    train_data_size=len(train_indices)
    train_val_indices = list(range(train_data_size))
    val_split = int(np.floor(val_split * train_data_size))
    if shuffle_dataset :
        np.random.seed(random_seed)
        np.random.shuffle(train_val_indices)
    train_indices, val_indices = train_val_indices[val_split:], train_val_indices[:val_split]



    # Creating PT data samplers and loaders:
    train_sampler = SubsetRandomSampler(train_indices)
    test_sampler = SubsetRandomSampler(test_indices)
    val_sampler = SubsetRandomSampler(val_indices)

    data_loader_train = torch.utils.data.DataLoader(dataset, batch_size=batch_size, 
                                              sampler=train_sampler)
    data_loader_test = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                                    sampler=test_sampler)

    data_loader_val = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                                    sampler=val_sampler)


   
    print(len(data_loader_train),len(data_loader_test),len(data_loader_val))
    
    return data_loader_train, data_loader_test, data_loader_val

# %%
data_loader_train, data_loader_test, data_loader_val=load_data(data_dir,.2,.2,32,(64,64))
# Out:
# 501 157 126

# %%
def plot_data_loader(data_loader, gridDims):
    
    fig, axes = plt.subplots(nrows=gridDims[0], ncols=gridDims[1], figsize=(5,5))
    dataiter = iter(data_loader)
    for i in range(gridDims[0]):
        for j in range(gridDims[1]):
            images, _ = next(dataiter)
            axes[i, j].imshow(np.transpose(images[0].numpy(), (1, 2, 0)))

# %%
plot_data_loader(data_loader_test,[2,2])
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
model = torch.hub.load('pytorch/vision:v0.10.0', 'densenet121', weights=None)
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0

# %%
optimizer = optim.Adam(model.parameters(),lr=0.001);
criterion = nn.CrossEntropyLoss()

# %%
model.to(device)

num_epochs = 20
total_steps = len(data_loader_train)
t1 = time.time()
accuracies = []
losses = []
accuracies_v = []
losses_v = []

for epoch in range(num_epochs):
    ti = 0;
    total_correct = 0;
    tl = 0.0
    for i, data in enumerate(data_loader_train):
        images, labels = data[0].to(device), data[1].to(device)
        labels=torch.flatten(labels)
        outputs = model(images)
        loss = criterion(outputs, labels)
        tl+=loss.item()
        # Backprop and optimisation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Train accuracy
        total = labels.size(0)
        ti+=total
        _,predicted = torch.max(outputs.data, 1)
        correct = (predicted == labels).sum().item()
        total_correct+= (predicted == labels).sum()

        if (i + 1) % 100 == 0:
            print('Epoch [{}/{}], Step [{}/{}], Train Loss: {:.4f}, Train Accuracy: {:.2f}%'
                  .format(epoch + 1, num_epochs, i + 1, total_steps, 
                          loss.item(),
                      (correct / total) * 100))
    # validation 
    total_correct_v = 0.0
    ti_v = 0
    tl_v = 0.0
    for _, data_v in enumerate(data_loader_val):
        images_v, labels_v = data_v[0].to(device), data_v[1].to(device)
        labels_v=torch.flatten(labels_v)
        outputs_v = model(images_v)
        loss_v = criterion(outputs_v,labels_v)
        valid_loss = loss_v.item() * labels_v.size(0)
        tl_v+=valid_loss
        # Validation accuracy
        total_v = labels_v.size(0)
        ti_v+=total_v
        _,predicted_v = torch.max(outputs_v.data, 1)
        correct_v = (predicted_v == labels_v).sum().item() 
        total_correct_v+= (predicted_v == labels_v).sum() 
    print('Epoch [{}/{}], Validation Loss: {:.4f}, Validation Accuracy: {:.2f}%'.format(epoch + 1, num_epochs, float(tl_v)/ti_v, total_correct_v / ti_v*100.0))
    accuracies_v.append(total_correct_v / ti_v*100.0)    
    losses_v.append(float(tl_v)/ti_v)  
    accuracies.append(total_correct/ti*100.0)
    losses.append(float(tl)/ti)
           
print("######## Training Finished in {} seconds ###########".format(time.time()-t1))
# Out:
# Epoch [1/20], Step [100/501], Train Loss: 1.1663, Train Accuracy: 50.00%
# Epoch [1/20], Step [200/501], Train Loss: 0.9814, Train Accuracy: 62.50%
# Epoch [1/20], Step [300/501], Train Loss: 0.5366, Train Accuracy: 81.25%
# Epoch [1/20], Step [400/501], Train Loss: 0.8261, Train Accuracy: 65.62%
# Epoch [1/20], Step [500/501], Train Loss: 0.7808, Train Accuracy: 68.75%
# Epoch [1/20], Validation Loss: 0.7337, Validation Accuracy: 74.19%
# Epoch [2/20], Step [100/501], Train Loss: 0.7578, Train Accuracy: 75.00%
# Epoch [2/20], Step [200/501], Train Loss: 0.6581, Train Accuracy: 71.88%
# Epoch [2/20], Step [300/501], Train Loss: 0.4239, Train Accuracy: 81.25%
# Epoch [2/20], Step [400/501], Train Loss: 0.3477, Train Accuracy: 87.50%
# Epoch [2/20], Step [500/501], Train Loss: 0.4069, Train Accuracy: 84.38%
# Epoch [2/20], Validation Loss: 0.4864, Validation Accuracy: 82.91%
# Epoch [3/20], Step [100/501], Train Loss: 0.5152, Train Accuracy: 78.12%
# Epoch [3/20], Step [200/501], Train Loss: 0.2897, Train Accuracy: 90.62%
# Epoch [3/20], Step [300/501], Train Loss: 0.3392, Train Accuracy: 90.62%
# Epoch [3/20], Step [400/501], Train Loss: 0.4041, Train Accuracy: 87.50%
# Epoch [3/20], Step [500/501], Train Loss: 0.6379, Train Accuracy: 75.00%
# Epoch [3/20], Validation Loss: 0.4142, Validation Accuracy: 85.59%
# Epoch [4/20], Step [100/501], Train Loss: 0.1914, Train Accuracy: 87.50%
# Epoch [4/20], Step [200/501], Train Loss: 0.1971, Train Accuracy: 93.75%
# Epoch [4/20], Step [300/501], Train Loss: 0.2768, Train Accuracy: 93.75%
# Epoch [4/20], Step [400/501], Train Loss: 0.4604, Train Accuracy: 81.25%
# Epoch [4/20], Step [500/501], Train Loss: 0.3901, Train Accuracy: 87.50%
# Epoch [4/20], Validation Loss: 0.3528, Validation Accuracy: 88.01%
# Epoch [5/20], Step [100/501], Train Loss: 0.1703, Train Accuracy: 93.75%
# Epoch [5/20], Step [200/501], Train Loss: 0.2880, Train Accuracy: 81.25%
# Epoch [5/20], Step [300/501], Train Loss: 0.3973, Train Accuracy: 84.38%
# Epoch [5/20], Step [400/501], Train Loss: 0.0888, Train Accuracy: 100.00%
# Epoch [5/20], Step [500/501], Train Loss: 0.3870, Train Accuracy: 84.38%
# Epoch [5/20], Validation Loss: 0.3302, Validation Accuracy: 89.38%
# Epoch [6/20], Step [100/501], Train Loss: 0.2746, Train Accuracy: 93.75%
# Epoch [6/20], Step [200/501], Train Loss: 0.3582, Train Accuracy: 90.62%
# Epoch [6/20], Step [300/501], Train Loss: 0.3570, Train Accuracy: 87.50%
# Epoch [6/20], Step [400/501], Train Loss: 0.0276, Train Accuracy: 100.00%
# Epoch [6/20], Step [500/501], Train Loss: 0.6058, Train Accuracy: 75.00%
# Epoch [6/20], Validation Loss: 0.2896, Validation Accuracy: 89.98%
# Epoch [7/20], Step [100/501], Train Loss: 0.3950, Train Accuracy: 93.75%
# Epoch [7/20], Step [200/501], Train Loss: 0.1105, Train Accuracy: 96.88%
# Epoch [7/20], Step [300/501], Train Loss: 0.3226, Train Accuracy: 84.38%
# Epoch [7/20], Step [400/501], Train Loss: 0.2576, Train Accuracy: 87.50%
# Epoch [7/20], Step [500/501], Train Loss: 0.4664, Train Accuracy: 87.50%
# Epoch [7/20], Validation Loss: 0.2366, Validation Accuracy: 91.68%
# Epoch [8/20], Step [100/501], Train Loss: 0.0766, Train Accuracy: 100.00%
# Epoch [8/20], Step [200/501], Train Loss: 0.3539, Train Accuracy: 90.62%
# Epoch [8/20], Step [300/501], Train Loss: 0.1326, Train Accuracy: 96.88%
# Epoch [8/20], Step [400/501], Train Loss: 0.2717, Train Accuracy: 84.38%
# Epoch [8/20], Step [500/501], Train Loss: 0.2824, Train Accuracy: 90.62%
# Epoch [8/20], Validation Loss: 0.2621, Validation Accuracy: 90.76%
# Epoch [9/20], Step [100/501], Train Loss: 0.2863, Train Accuracy: 90.62%
# Epoch [9/20], Step [200/501], Train Loss: 0.1253, Train Accuracy: 93.75%
# Epoch [9/20], Step [300/501], Train Loss: 0.0669, Train Accuracy: 96.88%
# Epoch [9/20], Step [400/501], Train Loss: 0.2262, Train Accuracy: 90.62%
# Epoch [9/20], Step [500/501], Train Loss: 0.0897, Train Accuracy: 96.88%
# Epoch [9/20], Validation Loss: 0.2535, Validation Accuracy: 91.51%
# Epoch [10/20], Step [100/501], Train Loss: 0.1348, Train Accuracy: 93.75%
# Epoch [10/20], Step [200/501], Train Loss: 0.3819, Train Accuracy: 87.50%
# Epoch [10/20], Step [300/501], Train Loss: 0.0796, Train Accuracy: 96.88%
# Epoch [10/20], Step [400/501], Train Loss: 0.3673, Train Accuracy: 81.25%
# Epoch [10/20], Step [500/501], Train Loss: 0.3032, Train Accuracy: 87.50%
# Epoch [10/20], Validation Loss: 0.2405, Validation Accuracy: 91.93%
# Epoch [11/20], Step [100/501], Train Loss: 0.2970, Train Accuracy: 87.50%
# Epoch [11/20], Step [200/501], Train Loss: 0.0658, Train Accuracy: 100.00%
# Epoch [11/20], Step [300/501], Train Loss: 0.0898, Train Accuracy: 96.88%
# Epoch [11/20], Step [400/501], Train Loss: 0.2238, Train Accuracy: 90.62%
# Epoch [11/20], Step [500/501], Train Loss: 0.1103, Train Accuracy: 96.88%
# Epoch [11/20], Validation Loss: 0.2431, Validation Accuracy: 91.93%
# Epoch [12/20], Step [100/501], Train Loss: 0.0829, Train Accuracy: 96.88%
# Epoch [12/20], Step [200/501], Train Loss: 0.0893, Train Accuracy: 93.75%
# Epoch [12/20], Step [300/501], Train Loss: 0.0501, Train Accuracy: 96.88%
# Epoch [12/20], Step [400/501], Train Loss: 0.0343, Train Accuracy: 100.00%
# Epoch [12/20], Step [500/501], Train Loss: 0.0553, Train Accuracy: 96.88%
# Epoch [12/20], Validation Loss: 0.2554, Validation Accuracy: 91.71%
# Epoch [13/20], Step [100/501], Train Loss: 0.1045, Train Accuracy: 96.88%
# Epoch [13/20], Step [200/501], Train Loss: 0.0381, Train Accuracy: 100.00%
# Epoch [13/20], Step [300/501], Train Loss: 0.0959, Train Accuracy: 93.75%
# Epoch [13/20], Step [400/501], Train Loss: 0.1621, Train Accuracy: 93.75%
# Epoch [13/20], Step [500/501], Train Loss: 0.1082, Train Accuracy: 96.88%
# Epoch [13/20], Validation Loss: 0.2778, Validation Accuracy: 91.91%
# Epoch [14/20], Step [100/501], Train Loss: 0.0780, Train Accuracy: 96.88%
# Epoch [14/20], Step [200/501], Train Loss: 0.0368, Train Accuracy: 100.00%
# Epoch [14/20], Step [300/501], Train Loss: 0.0927, Train Accuracy: 93.75%
# Epoch [14/20], Step [400/501], Train Loss: 0.0147, Train Accuracy: 100.00%
# Epoch [14/20], Step [500/501], Train Loss: 0.0306, Train Accuracy: 100.00%
# Epoch [14/20], Validation Loss: 0.2369, Validation Accuracy: 92.28%
# Epoch [15/20], Step [100/501], Train Loss: 0.1608, Train Accuracy: 96.88%
# Epoch [15/20], Step [200/501], Train Loss: 0.1881, Train Accuracy: 90.62%
# Epoch [15/20], Step [300/501], Train Loss: 0.0395, Train Accuracy: 100.00%
# Epoch [15/20], Step [400/501], Train Loss: 0.0579, Train Accuracy: 100.00%
# Epoch [15/20], Step [500/501], Train Loss: 0.0438, Train Accuracy: 100.00%
# Epoch [15/20], Validation Loss: 0.2213, Validation Accuracy: 93.08%
# Epoch [16/20], Step [100/501], Train Loss: 0.1102, Train Accuracy: 93.75%
# Epoch [16/20], Step [200/501], Train Loss: 0.0129, Train Accuracy: 100.00%
# Epoch [16/20], Step [300/501], Train Loss: 0.0119, Train Accuracy: 100.00%
# Epoch [16/20], Step [400/501], Train Loss: 0.1751, Train Accuracy: 96.88%
# Epoch [16/20], Step [500/501], Train Loss: 0.1955, Train Accuracy: 96.88%
# Epoch [16/20], Validation Loss: 0.2397, Validation Accuracy: 92.48%
# Epoch [17/20], Step [100/501], Train Loss: 0.0580, Train Accuracy: 100.00%
# Epoch [17/20], Step [200/501], Train Loss: 0.0376, Train Accuracy: 96.88%
# Epoch [17/20], Step [300/501], Train Loss: 0.2906, Train Accuracy: 93.75%
# Epoch [17/20], Step [400/501], Train Loss: 0.0871, Train Accuracy: 96.88%
# Epoch [17/20], Step [500/501], Train Loss: 0.0608, Train Accuracy: 96.88%
# Epoch [17/20], Validation Loss: 0.2292, Validation Accuracy: 93.13%
# Epoch [18/20], Step [100/501], Train Loss: 0.0145, Train Accuracy: 100.00%
# Epoch [18/20], Step [200/501], Train Loss: 0.0363, Train Accuracy: 100.00%
# Epoch [18/20], Step [300/501], Train Loss: 0.1069, Train Accuracy: 93.75%
# Epoch [18/20], Step [400/501], Train Loss: 0.0530, Train Accuracy: 100.00%
# Epoch [18/20], Step [500/501], Train Loss: 0.0151, Train Accuracy: 100.00%
# Epoch [18/20], Validation Loss: 0.2253, Validation Accuracy: 93.31%
# Epoch [19/20], Step [100/501], Train Loss: 0.0793, Train Accuracy: 96.88%
# Epoch [19/20], Step [200/501], Train Loss: 0.0576, Train Accuracy: 96.88%
# Epoch [19/20], Step [300/501], Train Loss: 0.0160, Train Accuracy: 100.00%
# Epoch [19/20], Step [400/501], Train Loss: 0.0086, Train Accuracy: 100.00%
# Epoch [19/20], Step [500/501], Train Loss: 0.0734, Train Accuracy: 93.75%
# Epoch [19/20], Validation Loss: 0.2512, Validation Accuracy: 92.61%
# Epoch [20/20], Step [100/501], Train Loss: 0.0199, Train Accuracy: 100.00%
# Epoch [20/20], Step [200/501], Train Loss: 0.0351, Train Accuracy: 100.00%
# Epoch [20/20], Step [300/501], Train Loss: 0.1144, Train Accuracy: 96.88%
# Epoch [20/20], Step [400/501], Train Loss: 0.0043, Train Accuracy: 100.00%
# Epoch [20/20], Step [500/501], Train Loss: 0.0151, Train Accuracy: 100.00%
# Epoch [20/20], Validation Loss: 0.2320, Validation Accuracy: 93.01%
# ######## Training Finished in 1979.4540572166443 seconds ###########

# %%
model.eval() 
with torch.no_grad(): 
 correct = 0
 total = 0
 for data in data_loader_test:
  images, labels = data[0].to(device), data[1].to(device)
  labels=torch.flatten(labels)
  outputs = model(images)
  _, predicted = torch.max(outputs.data, 1)
  total += labels.size(0)
  correct += (predicted == labels).sum().item()
print('Test Accuracy of the model on the {} test images: {} %'
  .format(total, (correct / total) * 100))
# Out:
# Test Accuracy of the model on the 5004 test images: 81.99440447641886 %

# %%
acc_list = [i.item() for i in accuracies]

# %%
plt.figure()
plt.xlabel('epochs')
plt.ylabel('Accuracy')
plt.title('Train Accuracy plot')
plt.plot(range(1,num_epochs+1),acc_list)
plt.legend(['Accuracy'])

# %%
plt.figure()
plt.xlabel('epochs')
plt.ylabel('Loss')
plt.title('Train Loss plot')
plt.plot(range(1,num_epochs+1),losses,'g')
plt.legend(['Loss'])

# %%
acc_list_v = [i.item() for i in accuracies_v]

# %%
plt.figure()
plt.xlabel('epochs')
plt.ylabel('Accuracy')
plt.title('Validation Accuracy plot')
plt.plot(range(1,num_epochs+1),acc_list_v)
plt.legend(['Accuracy'])

# %%
plt.figure()
plt.xlabel('epochs')
plt.ylabel('Loss')
plt.title('Validation Loss plot')
plt.plot(range(1,num_epochs+1),losses_v,'g')
plt.legend(['Loss'])
