# %%
import os
import torch
import torchvision
import tarfile
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchvision.datasets.utils import download_url
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from torch.utils.data import random_split
from torchvision.utils import make_grid
import matplotlib
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import glob
import torch.optim as optim
import time

import cv2
# %matplotlib inline

# %%
data_dir = './EuroSAT/'
print(os.listdir(data_dir))
# Out:
# ['Forest', 'River', '.DS_Store', 'Highway', 'AnnualCrop', 'SeaLake', 'HerbaceousVegetation', 'Industrial', 'Residential', 'PermanentCrop', 'Pasture']

# %%
file_list = glob.glob(data_dir+"*")
for class_path in file_list:
    class_name = class_path.split("/")[-1]
    print(class_name)
# Out:
# Forest
# River
# Highway
# AnnualCrop
# SeaLake
# HerbaceousVegetation
# Industrial
# Residential
# PermanentCrop
# Pasture

# %%
class CustomDataset(Dataset):
    def __init__(self,path,image_size):
        self.imgs_path = path
        file_list = glob.glob(self.imgs_path + "*")
        print(file_list)
        self.data = []
        for class_path in file_list:
            class_name = class_path.split("/")[-1]
            for img_path in glob.glob(class_path + "/*.jpg"):
                self.data.append([img_path, class_name])
        print(self.data)
        self.class_map = {"AnnualCrop" : 0, "Forest": 1,"HerbaceousVegetation": 2,"Highway": 3,"Industrial":4,"Pasture":5,"PermanentCrop":6,"Residential":7,"River":8,"SeaLake":9}
        self.img_dim = image_size
    def __len__(self):
        return len(self.data)
    def __getitem__(self, idx):
        img_path, class_name = self.data[idx]
        img = cv2.imread(img_path)
        img = cv2.resize(img, self.img_dim)
        class_id = self.class_map[class_name]
        transform = transforms.Compose([transforms.ToTensor()])
        img_tensor = transform(img)
        mean, std, var = torch.mean(img_tensor), torch.std(img_tensor), torch.var(img_tensor)
        img_tensor = (img_tensor-mean)/std
        class_id = torch.tensor([class_id])
        return img_tensor, class_id

# %%
from torch.utils.data.sampler import SubsetRandomSampler

def load_data(path, test_split, val_split, batch_size, input_size, shuffle_dataset=True,random_seed=42):
    dataset = CustomDataset(path,input_size)	
    # Creating data indices for training and test splits:
    dataset_size = len(dataset)
    train_test_indices = list(range(dataset_size))
    test_split = int(np.floor(test_split * dataset_size))
    if shuffle_dataset :
        np.random.seed(random_seed)
        np.random.shuffle(train_test_indices)
    train_indices, test_indices = train_test_indices[test_split:], train_test_indices[:test_split]


   # Creating data indices for training and validation splits:
   
    train_data_size=len(train_indices)
    train_val_indices = list(range(train_data_size))
    val_split = int(np.floor(val_split * train_data_size))
    if shuffle_dataset :
        np.random.seed(random_seed)
        np.random.shuffle(train_val_indices)
    train_indices, val_indices = train_val_indices[val_split:], train_val_indices[:val_split]



    # Creating PT data samplers and loaders:
    train_sampler = SubsetRandomSampler(train_indices)
    test_sampler = SubsetRandomSampler(test_indices)
    val_sampler = SubsetRandomSampler(val_indices)

    data_loader_train = torch.utils.data.DataLoader(dataset, batch_size=batch_size, 
                                              sampler=train_sampler)
    data_loader_test = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                                    sampler=test_sampler)

    data_loader_val = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                                    sampler=val_sampler)


   
    print(len(data_loader_train),len(data_loader_test),len(data_loader_val))
    
    return data_loader_train, data_loader_test, data_loader_val

# %%
data_loader_train, data_loader_test, data_loader_val=load_data(data_dir,.2,.2,32,(64,64))

print(len(data_loader_val))
# Out:
# ['./EuroSAT/Forest', './EuroSAT/River', './EuroSAT/Highway', './EuroSAT/AnnualCrop', './EuroSAT/SeaLake', './EuroSAT/HerbaceousVegetation', './EuroSAT/Industrial', './EuroSAT/Residential', './EuroSAT/PermanentCrop', './EuroSAT/Pasture']
# [['./EuroSAT/Forest/Forest_864.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2917.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2903.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_870.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_680.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_858.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2095.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2081.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1588.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_694.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1205.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_119.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1563.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1577.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1211.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2718.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1239.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_643.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2730.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2056.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_125.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_131.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2042.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2724.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_657.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2297.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1946.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_482.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_496.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1952.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2283.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2268.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1761.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1007.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1013.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_469.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1775.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1985.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_327.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2254.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2532.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_441.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_455.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2526.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2240.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1991.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_333.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1749.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1832.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_290.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2485.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2491.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1198.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1826.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_284.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1615.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1173.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_509.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1167.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1601.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2308.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_253.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1629.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2320.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2446.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_535.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_521.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2452.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2334.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_247.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_910.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2863.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2877.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_904.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2687.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_938.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2693.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_2678.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1371.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_15.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1417.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1403.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_1365.jpg', 'Forest'], ['./EuroSAT/Forest/Forest_737.jpg', 'Forest' ...
# 540 169 135
# 135

# %%
def plot_data_loader(data_loader, gridDims):
    
    fig, axes = plt.subplots(nrows=gridDims[0], ncols=gridDims[1], figsize=(5,5))
    dataiter = iter(data_loader)
    for i in range(gridDims[0]):
        for j in range(gridDims[1]):
            images, _ = next(dataiter)
            axes[i, j].imshow(np.transpose(images[0].numpy(), (1, 2, 0)))

# %%
plot_data_loader(data_loader_test,[2,2])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
model = torch.hub.load('pytorch/vision:v0.10.0', 'densenet121', weights=None)
# Out:
# Using cache found in /Users/madhavtripathi/.cache/torch/hub/pytorch_vision_v0.10.0

# %%
optimizer = optim.Adam(model.parameters(),lr=0.001);
criterion = nn.CrossEntropyLoss()

# %%
d = "cpu"
if torch.backends.mps.is_available() and torch.backends.mps.is_built():
    d = "mps"
elif torch.cuda.is_available():
    d = "cuda:0"
device = torch.device(d)

print("Device: {}".format(device))
# Out:
# Device: mps

# %%
model.to(device)

num_epochs = 30
total_steps = len(data_loader_train)
t1 = time.time()
accuracies = []
losses = []

for epoch in range(num_epochs):
    ti = 0;
    total_correct = 0;
    tl = 0.0;
    for i, data in enumerate(data_loader_train):
        images, labels = data[0].to(device), data[1].to(device)
        labels=torch.flatten(labels)
        outputs = model(images)
        loss = criterion(outputs, labels)
        tl+=loss.item()
        # Backprop and optimisation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Train accuracy
        total = labels.size(0)
        ti+=total
        _,predicted = torch.max(outputs.data, 1)
        correct = (predicted == labels).sum().item()
        total_correct+= (predicted == labels).sum()
        if (i + 1) % 100 == 0:
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'
                  .format(epoch + 1, num_epochs, i + 1, total_steps, loss.item(),
                      (correct / total) * 100))
    accuracies.append(total_correct/ti*100.0)
    losses.append(float(tl)/ti)
           
print("######## Training Finished in {} seconds ###########".format(time.time()-t1))
# Out:
# Epoch [1/30], Step [100/540], Loss: 0.5956, Accuracy: 75.00%
# Epoch [1/30], Step [200/540], Loss: 0.5309, Accuracy: 75.00%
# Epoch [1/30], Step [300/540], Loss: 0.3359, Accuracy: 87.50%
# Epoch [1/30], Step [400/540], Loss: 0.2163, Accuracy: 93.75%
# Epoch [1/30], Step [500/540], Loss: 0.2814, Accuracy: 87.50%
# Epoch [2/30], Step [100/540], Loss: 0.1448, Accuracy: 100.00%
# Epoch [2/30], Step [200/540], Loss: 0.4236, Accuracy: 84.38%
# Epoch [2/30], Step [300/540], Loss: 0.0898, Accuracy: 96.88%
# Epoch [2/30], Step [400/540], Loss: 0.9282, Accuracy: 71.88%
# Epoch [2/30], Step [500/540], Loss: 0.4873, Accuracy: 81.25%
# Epoch [3/30], Step [100/540], Loss: 0.2923, Accuracy: 90.62%
# Epoch [3/30], Step [200/540], Loss: 0.6625, Accuracy: 81.25%
# Epoch [3/30], Step [300/540], Loss: 0.0958, Accuracy: 96.88%
# Epoch [3/30], Step [400/540], Loss: 0.2487, Accuracy: 93.75%
# Epoch [3/30], Step [500/540], Loss: 0.1598, Accuracy: 93.75%
# Epoch [4/30], Step [100/540], Loss: 0.1287, Accuracy: 93.75%
# Epoch [4/30], Step [200/540], Loss: 0.3696, Accuracy: 93.75%
# Epoch [4/30], Step [300/540], Loss: 0.0516, Accuracy: 100.00%
# Epoch [4/30], Step [400/540], Loss: 0.3356, Accuracy: 84.38%
# Epoch [4/30], Step [500/540], Loss: 0.1171, Accuracy: 96.88%
# Epoch [5/30], Step [100/540], Loss: 0.2054, Accuracy: 96.88%
# Epoch [5/30], Step [200/540], Loss: 0.0619, Accuracy: 96.88%
# Epoch [5/30], Step [300/540], Loss: 0.1494, Accuracy: 96.88%
# Epoch [5/30], Step [400/540], Loss: 0.0487, Accuracy: 100.00%
# Epoch [5/30], Step [500/540], Loss: 0.3329, Accuracy: 90.62%
# Epoch [6/30], Step [100/540], Loss: 0.0051, Accuracy: 100.00%
# Epoch [6/30], Step [200/540], Loss: 0.0325, Accuracy: 100.00%
# Epoch [6/30], Step [300/540], Loss: 0.1703, Accuracy: 93.75%
# Epoch [6/30], Step [400/540], Loss: 0.2329, Accuracy: 90.62%
# Epoch [6/30], Step [500/540], Loss: 0.0322, Accuracy: 100.00%
# Epoch [7/30], Step [100/540], Loss: 0.0900, Accuracy: 96.88%
# Epoch [7/30], Step [200/540], Loss: 0.1869, Accuracy: 90.62%
# Epoch [7/30], Step [300/540], Loss: 0.0154, Accuracy: 100.00%
# Epoch [7/30], Step [400/540], Loss: 0.2603, Accuracy: 90.62%
# Epoch [7/30], Step [500/540], Loss: 0.2339, Accuracy: 96.88%
# Epoch [8/30], Step [100/540], Loss: 0.1203, Accuracy: 93.75%
# Epoch [8/30], Step [200/540], Loss: 0.0515, Accuracy: 100.00%
# Epoch [8/30], Step [300/540], Loss: 0.0656, Accuracy: 96.88%
# Epoch [8/30], Step [400/540], Loss: 0.0683, Accuracy: 96.88%
# Epoch [8/30], Step [500/540], Loss: 0.1023, Accuracy: 96.88%
# Epoch [9/30], Step [100/540], Loss: 0.4509, Accuracy: 93.75%
# Epoch [9/30], Step [200/540], Loss: 0.0840, Accuracy: 96.88%
# Epoch [9/30], Step [300/540], Loss: 0.2306, Accuracy: 93.75%
# Epoch [9/30], Step [400/540], Loss: 0.2817, Accuracy: 87.50%
# Epoch [9/30], Step [500/540], Loss: 0.1445, Accuracy: 96.88%
# Epoch [10/30], Step [100/540], Loss: 0.2267, Accuracy: 90.62%
# Epoch [10/30], Step [200/540], Loss: 0.1257, Accuracy: 93.75%
# Epoch [10/30], Step [300/540], Loss: 0.1085, Accuracy: 96.88%
# Epoch [10/30], Step [400/540], Loss: 0.1703, Accuracy: 93.75%
# Epoch [10/30], Step [500/540], Loss: 0.1236, Accuracy: 96.88%
# Epoch [11/30], Step [100/540], Loss: 0.0931, Accuracy: 93.75%
# Epoch [11/30], Step [200/540], Loss: 0.1085, Accuracy: 96.88%
# Epoch [11/30], Step [300/540], Loss: 0.0469, Accuracy: 96.88%
# Epoch [11/30], Step [400/540], Loss: 0.0366, Accuracy: 96.88%
# Epoch [11/30], Step [500/540], Loss: 0.0131, Accuracy: 100.00%
# Epoch [12/30], Step [100/540], Loss: 0.2469, Accuracy: 90.62%
# Epoch [12/30], Step [200/540], Loss: 0.1002, Accuracy: 96.88%
# Epoch [12/30], Step [300/540], Loss: 0.0148, Accuracy: 100.00%
# Epoch [12/30], Step [400/540], Loss: 0.0025, Accuracy: 100.00%
# Epoch [12/30], Step [500/540], Loss: 0.0864, Accuracy: 96.88%
# Epoch [13/30], Step [100/540], Loss: 0.0189, Accuracy: 100.00%
# Epoch [13/30], Step [200/540], Loss: 0.0936, Accuracy: 96.88%
# Epoch [13/30], Step [300/540], Loss: 0.0768, Accuracy: 96.88%
# Epoch [13/30], Step [400/540], Loss: 0.0039, Accuracy: 100.00%
# Epoch [13/30], Step [500/540], Loss: 0.1377, Accuracy: 93.75%
# Epoch [14/30], Step [100/540], Loss: 0.0306, Accuracy: 96.88%
# Epoch [14/30], Step [200/540], Loss: 0.1261, Accuracy: 93.75%
# Epoch [14/30], Step [300/540], Loss: 0.0883, Accuracy: 96.88%
# Epoch [14/30], Step [400/540], Loss: 0.1990, Accuracy: 93.75%
# Epoch [14/30], Step [500/540], Loss: 0.0527, Accuracy: 96.88%
# Epoch [15/30], Step [100/540], Loss: 0.0248, Accuracy: 100.00%
# Epoch [15/30], Step [200/540], Loss: 0.0023, Accuracy: 100.00%
# Epoch [15/30], Step [300/540], Loss: 0.0019, Accuracy: 100.00%
# Epoch [15/30], Step [400/540], Loss: 0.1150, Accuracy: 93.75%
# Epoch [15/30], Step [500/540], Loss: 0.0152, Accuracy: 100.00%
# Epoch [16/30], Step [100/540], Loss: 0.3205, Accuracy: 93.75%
# Epoch [16/30], Step [200/540], Loss: 0.0637, Accuracy: 96.88%
# Epoch [16/30], Step [300/540], Loss: 0.0377, Accuracy: 96.88%
# Epoch [16/30], Step [400/540], Loss: 0.0778, Accuracy: 96.88%
# Epoch [16/30], Step [500/540], Loss: 0.0172, Accuracy: 100.00%
# Epoch [17/30], Step [100/540], Loss: 0.0168, Accuracy: 100.00%
# Epoch [17/30], Step [200/540], Loss: 0.0347, Accuracy: 96.88%
# Epoch [17/30], Step [300/540], Loss: 0.0662, Accuracy: 96.88%
# Epoch [17/30], Step [400/540], Loss: 0.0148, Accuracy: 100.00%
# Epoch [17/30], Step [500/540], Loss: 0.0070, Accuracy: 100.00%
# Epoch [18/30], Step [100/540], Loss: 0.0122, Accuracy: 100.00%
# Epoch [18/30], Step [200/540], Loss: 0.0331, Accuracy: 96.88%
# Epoch [18/30], Step [300/540], Loss: 0.0902, Accuracy: 96.88%
# Epoch [18/30], Step [400/540], Loss: 0.0036, Accuracy: 100.00%
# Epoch [18/30], Step [500/540], Loss: 0.3564, Accuracy: 90.62%
# Epoch [19/30], Step [100/540], Loss: 0.0959, Accuracy: 96.88%
# Epoch [19/30], Step [200/540], Loss: 0.0086, Accuracy: 100.00%
# Epoch [19/30], Step [300/540], Loss: 0.1645, Accuracy: 93.75%
# Epoch [19/30], Step [400/540], Loss: 0.0731, Accuracy: 96.88%
# Epoch [19/30], Step [500/540], Loss: 0.0847, Accuracy: 96.88%
# Epoch [20/30], Step [100/540], Loss: 0.0961, Accuracy: 96.88%
# Epoch [20/30], Step [200/540], Loss: 0.0141, Accuracy: 100.00%
# Epoch [20/30], Step [300/540], Loss: 0.0210, Accuracy: 100.00%
# Epoch [20/30], Step [400/540], Loss: 0.0155, Accuracy: 100.00%
# Epoch [20/30], Step [500/540], Loss: 0.0186, Accuracy: 100.00%
# Epoch [21/30], Step [100/540], Loss: 0.1224, Accuracy: 93.75%
# Epoch [21/30], Step [200/540], Loss: 0.0022, Accuracy: 100.00%
# Epoch [21/30], Step [300/540], Loss: 0.2973, Accuracy: 96.88%
# Epoch [21/30], Step [400/540], Loss: 0.0026, Accuracy: 100.00%
# Epoch [21/30], Step [500/540], Loss: 0.0098, Accuracy: 100.00%
# Epoch [22/30], Step [100/540], Loss: 0.0775, Accuracy: 96.88%
# Epoch [22/30], Step [200/540], Loss: 0.0200, Accuracy: 100.00%
# Epoch [22/30], Step [300/540], Loss: 0.0030, Accuracy: 100.00%
# Epoch [22/30], Step [400/540], Loss: 0.0378, Accuracy: 96.88%
# Epoch [22/30], Step [500/540], Loss: 0.0204, Accuracy: 100.00%
# Epoch [23/30], Step [100/540], Loss: 0.1716, Accuracy: 93.75%
# Epoch [23/30], Step [200/540], Loss: 0.0776, Accuracy: 96.88%
# Epoch [23/30], Step [300/540], Loss: 0.0071, Accuracy: 100.00%
# Epoch [23/30], Step [400/540], Loss: 0.0202, Accuracy: 100.00%
# Epoch [23/30], Step [500/540], Loss: 0.0741, Accuracy: 96.88%
# Epoch [24/30], Step [100/540], Loss: 0.0067, Accuracy: 100.00%
# Epoch [24/30], Step [200/540], Loss: 0.0201, Accuracy: 100.00%
# Epoch [24/30], Step [300/540], Loss: 0.0175, Accuracy: 100.00%
# Epoch [24/30], Step [400/540], Loss: 0.0139, Accuracy: 100.00%
# Epoch [24/30], Step [500/540], Loss: 0.0515, Accuracy: 96.88%
# Epoch [25/30], Step [100/540], Loss: 0.0096, Accuracy: 100.00%
# Epoch [25/30], Step [200/540], Loss: 0.0065, Accuracy: 100.00%
# Epoch [25/30], Step [300/540], Loss: 0.0392, Accuracy: 96.88%
# Epoch [25/30], Step [400/540], Loss: 0.0029, Accuracy: 100.00%
# Epoch [25/30], Step [500/540], Loss: 0.0678, Accuracy: 96.88%
# Epoch [26/30], Step [100/540], Loss: 0.0535, Accuracy: 96.88%
# Epoch [26/30], Step [200/540], Loss: 0.0006, Accuracy: 100.00%
# Epoch [26/30], Step [300/540], Loss: 0.1185, Accuracy: 96.88%
# Epoch [26/30], Step [400/540], Loss: 0.0028, Accuracy: 100.00%
# Epoch [26/30], Step [500/540], Loss: 0.0110, Accuracy: 100.00%
# Epoch [27/30], Step [100/540], Loss: 0.0058, Accuracy: 100.00%
# Epoch [27/30], Step [200/540], Loss: 0.1213, Accuracy: 93.75%
# Epoch [27/30], Step [300/540], Loss: 0.0138, Accuracy: 100.00%
# Epoch [27/30], Step [400/540], Loss: 0.0066, Accuracy: 100.00%
# Epoch [27/30], Step [500/540], Loss: 0.0980, Accuracy: 96.88%
# Epoch [28/30], Step [100/540], Loss: 0.0362, Accuracy: 96.88%
# Epoch [28/30], Step [200/540], Loss: 0.0023, Accuracy: 100.00%
# Epoch [28/30], Step [300/540], Loss: 0.0344, Accuracy: 100.00%
# Epoch [28/30], Step [400/540], Loss: 0.0591, Accuracy: 96.88%
# Epoch [28/30], Step [500/540], Loss: 0.0050, Accuracy: 100.00%
# Epoch [29/30], Step [100/540], Loss: 0.0585, Accuracy: 93.75%
# Epoch [29/30], Step [200/540], Loss: 0.0140, Accuracy: 100.00%
# Epoch [29/30], Step [300/540], Loss: 0.0110, Accuracy: 100.00%
# Epoch [29/30], Step [400/540], Loss: 0.0021, Accuracy: 100.00%
# Epoch [29/30], Step [500/540], Loss: 0.0088, Accuracy: 100.00%
# Epoch [30/30], Step [100/540], Loss: 0.0017, Accuracy: 100.00%
# Epoch [30/30], Step [200/540], Loss: 0.0054, Accuracy: 100.00%
# Epoch [30/30], Step [300/540], Loss: 0.0149, Accuracy: 100.00%
# Epoch [30/30], Step [400/540], Loss: 0.0017, Accuracy: 100.00%
# Epoch [30/30], Step [500/540], Loss: 0.1005, Accuracy: 96.88%
# ######## Training Finished in 31388.562399864197 seconds ###########

# %%
model.eval() 
with torch.no_grad(): 
 correct = 0
 total = 0
 for data in data_loader_test:
  images, labels = data[0].to(device), data[1].to(device)
  labels=torch.flatten(labels)
  outputs = model(images)
  _, predicted = torch.max(outputs.data, 1)
  total += labels.size(0)
  correct += (predicted == labels).sum().item()
print('Test Accuracy of the model on the {} test images: {} %'
  .format(total, (correct / total) * 100))
# Out:
# Test Accuracy of the model on the 5400 test images: 80.7962962962963 %

# %%
acc_list = [i.item() for i in accuracies]
plt.figure()
plt.xlabel('epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy plot')
plt.plot(range(1,num_epochs+1),acc_list)
plt.legend(['Accuracy'])

# %%
plt.figure()
plt.xlabel('epochs')
plt.ylabel('Loss')
plt.title('Loss plot')
plt.plot(range(1,num_epochs+1),losses,'g')
plt.legend(['Loss'])
