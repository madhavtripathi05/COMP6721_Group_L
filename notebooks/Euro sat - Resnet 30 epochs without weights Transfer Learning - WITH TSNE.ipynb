# %%
import os
import torch
import torchvision
import tarfile
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchvision.datasets.utils import download_url
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from torch.utils.data import random_split
from torchvision.utils import make_grid
import matplotlib
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import glob
import torch.optim as optim
import time
from torchvision import transforms as T, models


import cv2
# %matplotlib inline

# %%
data_dir = 'Archive/EuroSAT/'
print(os.listdir(data_dir))
# Out:
# ['Forest', 'River', '.DS_Store', 'Highway', 'AnnualCrop', 'SeaLake', 'HerbaceousVegetation', 'Industrial', 'Residential', 'PermanentCrop', 'Pasture']

# %%
file_list = glob.glob(data_dir+"*")
for class_path in file_list:
    class_name = class_path.split("/")[-1]
    print(class_name)
# Out:
# Forest
# River
# Highway
# AnnualCrop
# SeaLake
# HerbaceousVegetation
# Industrial
# Residential
# PermanentCrop
# Pasture

# %%
class CustomDataset(Dataset):
    def __init__(self,path,image_size):
        self.imgs_path = path
        file_list = glob.glob(self.imgs_path + "*")
        print(file_list)
        self.data = []
        for class_path in file_list:
            class_name = class_path.split("/")[-1]
            for img_path in glob.glob(class_path + "/*.jpg"):
                self.data.append([img_path, class_name])
        print(self.data)
        self.class_map = {"AnnualCrop" : 0, "Forest": 1,"HerbaceousVegetation": 2,"Highway": 3,"Industrial":4,"Pasture":5,"PermanentCrop":6,"Residential":7,"River":8,"SeaLake":9}
        self.img_dim = image_size
    def __len__(self):
        return len(self.data)
    def __getitem__(self, idx):
        img_path, class_name = self.data[idx]
        img = cv2.imread(img_path)
        img = cv2.resize(img, self.img_dim)
        class_id = self.class_map[class_name]
        transform = transforms.Compose([transforms.ToTensor()])
        img_tensor = transform(img)
        mean, std, var = torch.mean(img_tensor), torch.std(img_tensor), torch.var(img_tensor)
        img_tensor = (img_tensor-mean)/std
        class_id = torch.tensor([class_id])
        return img_tensor, class_id

# %%
from torch.utils.data.sampler import SubsetRandomSampler

def load_data(path, test_split, val_split, batch_size, input_size, shuffle_dataset=True,random_seed=42):
    dataset = CustomDataset(path,input_size)	
    # Creating data indices for training and test splits:
    dataset_size = len(dataset)
    train_test_indices = list(range(dataset_size))
    test_split = int(np.floor(test_split * dataset_size))
    if shuffle_dataset :
        np.random.seed(random_seed)
        np.random.shuffle(train_test_indices)
    train_indices, test_indices = train_test_indices[test_split:], train_test_indices[:test_split]


   # Creating data indices for training and validation splits:
   
    train_data_size=len(train_indices)
    train_val_indices = list(range(train_data_size))
    val_split = int(np.floor(val_split * train_data_size))
    if shuffle_dataset :
        np.random.seed(random_seed)
        np.random.shuffle(train_val_indices)
    train_indices, val_indices = train_val_indices[val_split:], train_val_indices[:val_split]



    # Creating PT data samplers and loaders:
    train_sampler = SubsetRandomSampler(train_indices)
    test_sampler = SubsetRandomSampler(test_indices)
    val_sampler = SubsetRandomSampler(val_indices)

    data_loader_train = torch.utils.data.DataLoader(dataset, batch_size=batch_size, 
                                              sampler=train_sampler)
    data_loader_test = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                                    sampler=test_sampler)

    data_loader_val = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                                    sampler=val_sampler)


   
    print(len(data_loader_train),len(data_loader_test),len(data_loader_val))
    
    return data_loader_train, data_loader_test, data_loader_val

# %%
data_loader_train, data_loader_test, data_loader_val=load_data(data_dir,.2,.2,32,(64,64))

print(len(data_loader_val))
# Out:
# ['Archive/EuroSAT/Forest', 'Archive/EuroSAT/River', 'Archive/EuroSAT/Highway', 'Archive/EuroSAT/AnnualCrop', 'Archive/EuroSAT/SeaLake', 'Archive/EuroSAT/HerbaceousVegetation', 'Archive/EuroSAT/Industrial', 'Archive/EuroSAT/Residential', 'Archive/EuroSAT/PermanentCrop', 'Archive/EuroSAT/Pasture']
# [['Archive/EuroSAT/Forest/Forest_864.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2917.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2903.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_870.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_680.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_858.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2095.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2081.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_1588.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_694.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_1205.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_119.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_1563.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_1577.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_1211.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2718.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_1239.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_643.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2730.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2056.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_125.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_131.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2042.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2724.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_657.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2297.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_1946.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_482.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_496.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_1952.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2283.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2268.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_1761.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_1007.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_1013.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_469.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_1775.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_1985.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_327.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2254.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2532.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_441.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_455.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2526.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2240.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_1991.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_333.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_1749.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_1832.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_290.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2485.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2491.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_1198.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_1826.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_284.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_1615.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_1173.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_509.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_1167.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_1601.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2308.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_253.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_1629.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2320.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2446.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_535.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_521.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2452.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2334.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_247.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_910.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2863.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_2877.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Forest_904.jpg', 'Forest'], ['Archive/EuroSAT/Forest/Fore ...
# 540 169 135
# 135

# %%
def plot_data_loader(data_loader, gridDims):
    fig, axes = plt.subplots(nrows=gridDims[0], ncols=gridDims[1], figsize=(5,5))
    dataiter = iter(data_loader)
    for i in range(gridDims[0]):
        for j in range(gridDims[1]):
            images, _ = next(dataiter)
            axes[i, j].imshow(np.transpose(images[0].numpy(), (1, 2, 0)))

# %%
plot_data_loader(data_loader_test,[2,2])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
 model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)

# %%
d = "cpu"
if torch.backends.mps.is_available() and torch.backends.mps.is_built():
    d = "mps"
elif torch.cuda.is_available():
    d = "cuda:0"
device = torch.device(d)

print("Device: {}".format(device))
# Out:
# Device: mps

# %%
import torch
import torch.backends.cudnn as cudnn
import torchvision
import torchvision.transforms as transforms
import torchvision.models as models

import argparse
import os

import numpy as np
import pandas as pd
# from tsne import bh_sne
from sklearn.manifold import TSNE
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#TSNE
sat_map ={0:"AnnualCrop", 1:"Forest",2:"HerbaceousVegetation",3:"Highway",4:"Industrial",5:"Pasture",6:"PermanentCrop",7:"Residential",8:"River",9:"SeaLake"}


model.to(device)

model.eval()
targets_list = []
outputs_list = []

with torch.no_grad():
    for idx, (inputs, targets) in enumerate(data_loader_train):
        inputs = inputs.to(device)
        targets = targets.to(device)
        targets_np = targets.data.cpu().numpy()

        outputs = model(inputs)
        outputs_np = outputs.data.cpu().numpy()

        targets_list.append(targets_np)
        outputs_list.append(outputs_np)

targets = np.concatenate(targets_list, axis=0)
outputs = np.concatenate(outputs_list, axis=0).astype(np.float64)

# %%
import pandas as pd
from sklearn.manifold import TSNE
import seaborn as sns
import matplotlib.pyplot as plt
print('generating t-SNE plot...')


tsne = TSNE(random_state=0)
tsne_output = tsne.fit_transform(outputs)

df = pd.DataFrame(tsne_output, columns=['x', 'y'])
df.insert(2, "targets", targets, True)
df.loc[:, 'targets'] = df.targets.map(sat_map)


plt.rcParams['figure.figsize'] = 10, 10

sns.scatterplot(
        x='x', y='y',
        hue='targets',
        palette=sns.color_palette("hls", 10),
        data=df,
        marker='o',
        legend="full",
        alpha=0.5
)

plt.xticks([])
plt.yticks([])
plt.xlabel('')
plt.ylabel('')

print('done!')
# Out:
# generating t-SNE plot...
# /Users/priyangpatel/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/priyangpatel/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /var/folders/mz/c6q_6p393sq4xcqpm9k620p00000gn/T/ipykernel_15001/3887831682.py:18: UserWarning: The palette list has more values (10) than needed (8), which may not be intended.
#   sns.scatterplot(
# done!

# %%
optimizer = optim.Adam(model.parameters(),lr=0.001);
criterion = nn.CrossEntropyLoss()

# %%
d = "cpu"
if torch.backends.mps.is_available() and torch.backends.mps.is_built():
    d = "mps"
elif torch.cuda.is_available():
    d = "cuda:0"
device = torch.device(d)

print("Device: {}".format(device))
# Out:
# Device: mps

# %%
model.to(device)

num_epochs = 30
total_steps = len(data_loader_train)
t1 = time.time()
accuracies = []
losses = []

for epoch in range(num_epochs):
    ti = 0;
    total_correct = 0;
    tl = 0.0;
    for i, data in enumerate(data_loader_train):
        images, labels = data[0].to(device), data[1].to(device)
        labels=torch.flatten(labels)
        outputs = model(images)
        loss = criterion(outputs, labels)
        tl+=loss.item()
        # Backprop and optimisation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Train accuracy
        total = labels.size(0)
        ti+=total
        _,predicted = torch.max(outputs.data, 1)
        correct = (predicted == labels).sum().item()
        total_correct+= (predicted == labels).sum()
        if (i + 1) % 100 == 0:
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'
                  .format(epoch + 1, num_epochs, i + 1, total_steps, loss.item(),
                      (correct / total) * 100))
    accuracies.append(total_correct/ti*100.0)
    losses.append(float(tl)/ti)
           
print("######## Training Finished in {} seconds ###########".format(time.time()-t1))
# Out:
# Epoch [1/30], Step [100/540], Loss: 1.2962, Accuracy: 34.38%
# Epoch [1/30], Step [200/540], Loss: 1.2099, Accuracy: 46.88%
# Epoch [1/30], Step [300/540], Loss: 0.9139, Accuracy: 71.88%
# Epoch [1/30], Step [400/540], Loss: 1.2405, Accuracy: 50.00%
# Epoch [1/30], Step [500/540], Loss: 0.9294, Accuracy: 65.62%
# Epoch [2/30], Step [100/540], Loss: 0.7423, Accuracy: 78.12%
# Epoch [2/30], Step [200/540], Loss: 0.8337, Accuracy: 78.12%
# Epoch [2/30], Step [300/540], Loss: 0.9962, Accuracy: 62.50%
# Epoch [2/30], Step [400/540], Loss: 0.3296, Accuracy: 87.50%
# Epoch [2/30], Step [500/540], Loss: 1.1073, Accuracy: 68.75%
# Epoch [3/30], Step [100/540], Loss: 0.4893, Accuracy: 84.38%
# Epoch [3/30], Step [200/540], Loss: 0.7680, Accuracy: 75.00%
# Epoch [3/30], Step [300/540], Loss: 0.6141, Accuracy: 75.00%
# Epoch [3/30], Step [400/540], Loss: 0.4447, Accuracy: 87.50%
# Epoch [3/30], Step [500/540], Loss: 0.2491, Accuracy: 87.50%
# Epoch [4/30], Step [100/540], Loss: 0.1232, Accuracy: 96.88%
# Epoch [4/30], Step [200/540], Loss: 0.7232, Accuracy: 81.25%
# Epoch [4/30], Step [300/540], Loss: 0.3074, Accuracy: 90.62%
# Epoch [4/30], Step [400/540], Loss: 0.2066, Accuracy: 90.62%
# Epoch [4/30], Step [500/540], Loss: 0.3131, Accuracy: 93.75%
# Epoch [5/30], Step [100/540], Loss: 0.1776, Accuracy: 93.75%
# Epoch [5/30], Step [200/540], Loss: 0.4666, Accuracy: 84.38%
# Epoch [5/30], Step [300/540], Loss: 0.6303, Accuracy: 81.25%
# Epoch [5/30], Step [400/540], Loss: 0.2406, Accuracy: 90.62%
# Epoch [5/30], Step [500/540], Loss: 0.2987, Accuracy: 90.62%
# Epoch [6/30], Step [100/540], Loss: 0.1151, Accuracy: 100.00%
# Epoch [6/30], Step [200/540], Loss: 0.3511, Accuracy: 90.62%
# Epoch [6/30], Step [300/540], Loss: 0.4368, Accuracy: 87.50%
# Epoch [6/30], Step [400/540], Loss: 0.0998, Accuracy: 93.75%
# Epoch [6/30], Step [500/540], Loss: 0.3345, Accuracy: 84.38%
# Epoch [7/30], Step [100/540], Loss: 0.2183, Accuracy: 90.62%
# Epoch [7/30], Step [200/540], Loss: 0.1540, Accuracy: 93.75%
# Epoch [7/30], Step [300/540], Loss: 0.1232, Accuracy: 96.88%
# Epoch [7/30], Step [400/540], Loss: 0.5101, Accuracy: 84.38%
# Epoch [7/30], Step [500/540], Loss: 0.3568, Accuracy: 90.62%
# Epoch [8/30], Step [100/540], Loss: 0.0371, Accuracy: 100.00%
# Epoch [8/30], Step [200/540], Loss: 0.1011, Accuracy: 96.88%
# Epoch [8/30], Step [300/540], Loss: 0.1959, Accuracy: 90.62%
# Epoch [8/30], Step [400/540], Loss: 0.1549, Accuracy: 96.88%
# Epoch [8/30], Step [500/540], Loss: 0.2571, Accuracy: 93.75%
# Epoch [9/30], Step [100/540], Loss: 0.2952, Accuracy: 90.62%
# Epoch [9/30], Step [200/540], Loss: 0.4598, Accuracy: 87.50%
# Epoch [9/30], Step [300/540], Loss: 0.2185, Accuracy: 93.75%
# Epoch [9/30], Step [400/540], Loss: 0.1471, Accuracy: 96.88%
# Epoch [9/30], Step [500/540], Loss: 0.0332, Accuracy: 100.00%
# Epoch [10/30], Step [100/540], Loss: 0.4210, Accuracy: 81.25%
# Epoch [10/30], Step [200/540], Loss: 0.2786, Accuracy: 87.50%
# Epoch [10/30], Step [300/540], Loss: 0.1325, Accuracy: 93.75%
# Epoch [10/30], Step [400/540], Loss: 0.2295, Accuracy: 90.62%
# Epoch [10/30], Step [500/540], Loss: 0.2656, Accuracy: 90.62%
# Epoch [11/30], Step [100/540], Loss: 0.0422, Accuracy: 100.00%
# Epoch [11/30], Step [200/540], Loss: 0.0504, Accuracy: 100.00%
# Epoch [11/30], Step [300/540], Loss: 0.2413, Accuracy: 90.62%
# Epoch [11/30], Step [400/540], Loss: 0.3778, Accuracy: 87.50%
# Epoch [11/30], Step [500/540], Loss: 0.1787, Accuracy: 93.75%
# Epoch [12/30], Step [100/540], Loss: 0.0288, Accuracy: 100.00%
# Epoch [12/30], Step [200/540], Loss: 0.1826, Accuracy: 96.88%
# Epoch [12/30], Step [300/540], Loss: 0.0574, Accuracy: 96.88%
# Epoch [12/30], Step [400/540], Loss: 0.2401, Accuracy: 93.75%
# Epoch [12/30], Step [500/540], Loss: 0.1253, Accuracy: 93.75%
# Epoch [13/30], Step [100/540], Loss: 0.0489, Accuracy: 100.00%
# Epoch [13/30], Step [200/540], Loss: 0.0708, Accuracy: 96.88%
# Epoch [13/30], Step [300/540], Loss: 0.0176, Accuracy: 100.00%
# Epoch [13/30], Step [400/540], Loss: 0.2203, Accuracy: 96.88%
# Epoch [13/30], Step [500/540], Loss: 0.1166, Accuracy: 96.88%
# Epoch [14/30], Step [100/540], Loss: 0.0592, Accuracy: 96.88%
# Epoch [14/30], Step [200/540], Loss: 0.1442, Accuracy: 96.88%
# Epoch [14/30], Step [300/540], Loss: 0.1452, Accuracy: 93.75%
# Epoch [14/30], Step [400/540], Loss: 0.2545, Accuracy: 90.62%
# Epoch [14/30], Step [500/540], Loss: 0.0671, Accuracy: 96.88%
# Epoch [15/30], Step [100/540], Loss: 0.1267, Accuracy: 96.88%
# Epoch [15/30], Step [200/540], Loss: 0.0155, Accuracy: 100.00%
# Epoch [15/30], Step [300/540], Loss: 0.0196, Accuracy: 100.00%
# Epoch [15/30], Step [400/540], Loss: 0.0576, Accuracy: 100.00%
# Epoch [15/30], Step [500/540], Loss: 0.1463, Accuracy: 90.62%
# Epoch [16/30], Step [100/540], Loss: 0.0644, Accuracy: 96.88%
# Epoch [16/30], Step [200/540], Loss: 0.1130, Accuracy: 96.88%
# Epoch [16/30], Step [300/540], Loss: 0.0270, Accuracy: 100.00%
# Epoch [16/30], Step [400/540], Loss: 0.0347, Accuracy: 96.88%
# Epoch [16/30], Step [500/540], Loss: 0.0414, Accuracy: 100.00%
# Epoch [17/30], Step [100/540], Loss: 0.1531, Accuracy: 96.88%
# Epoch [17/30], Step [200/540], Loss: 0.0050, Accuracy: 100.00%
# Epoch [17/30], Step [300/540], Loss: 0.1655, Accuracy: 90.62%
# Epoch [17/30], Step [400/540], Loss: 0.0833, Accuracy: 96.88%
# Epoch [17/30], Step [500/540], Loss: 0.0748, Accuracy: 93.75%
# Epoch [18/30], Step [100/540], Loss: 0.2705, Accuracy: 93.75%
# Epoch [18/30], Step [200/540], Loss: 0.0778, Accuracy: 96.88%
# Epoch [18/30], Step [300/540], Loss: 0.1186, Accuracy: 96.88%
# Epoch [18/30], Step [400/540], Loss: 0.0269, Accuracy: 100.00%
# Epoch [18/30], Step [500/540], Loss: 0.0349, Accuracy: 96.88%
# Epoch [19/30], Step [100/540], Loss: 0.2817, Accuracy: 96.88%
# Epoch [19/30], Step [200/540], Loss: 0.1475, Accuracy: 96.88%
# Epoch [19/30], Step [300/540], Loss: 0.1915, Accuracy: 96.88%
# Epoch [19/30], Step [400/540], Loss: 0.1021, Accuracy: 93.75%
# Epoch [19/30], Step [500/540], Loss: 0.2872, Accuracy: 96.88%
# Epoch [20/30], Step [100/540], Loss: 0.0671, Accuracy: 100.00%
# Epoch [20/30], Step [200/540], Loss: 0.0030, Accuracy: 100.00%
# Epoch [20/30], Step [300/540], Loss: 0.3507, Accuracy: 87.50%
# Epoch [20/30], Step [400/540], Loss: 0.0608, Accuracy: 96.88%
# Epoch [20/30], Step [500/540], Loss: 0.0560, Accuracy: 96.88%
# Epoch [21/30], Step [100/540], Loss: 0.0208, Accuracy: 100.00%
# Epoch [21/30], Step [200/540], Loss: 0.0332, Accuracy: 100.00%
# Epoch [21/30], Step [300/540], Loss: 0.0352, Accuracy: 96.88%
# Epoch [21/30], Step [400/540], Loss: 0.2216, Accuracy: 93.75%
# Epoch [21/30], Step [500/540], Loss: 0.1388, Accuracy: 96.88%
# Epoch [22/30], Step [100/540], Loss: 0.1313, Accuracy: 96.88%
# Epoch [22/30], Step [200/540], Loss: 0.0112, Accuracy: 100.00%
# Epoch [22/30], Step [300/540], Loss: 0.1052, Accuracy: 96.88%
# Epoch [22/30], Step [400/540], Loss: 0.1272, Accuracy: 96.88%
# Epoch [22/30], Step [500/540], Loss: 0.1504, Accuracy: 93.75%
# Epoch [23/30], Step [100/540], Loss: 0.1921, Accuracy: 96.88%
# Epoch [23/30], Step [200/540], Loss: 0.0010, Accuracy: 100.00%
# Epoch [23/30], Step [300/540], Loss: 0.0450, Accuracy: 96.88%
# Epoch [23/30], Step [400/540], Loss: 0.0602, Accuracy: 96.88%
# Epoch [23/30], Step [500/540], Loss: 0.0126, Accuracy: 100.00%
# Epoch [24/30], Step [100/540], Loss: 0.0291, Accuracy: 100.00%
# Epoch [24/30], Step [200/540], Loss: 0.0986, Accuracy: 93.75%
# Epoch [24/30], Step [300/540], Loss: 0.0020, Accuracy: 100.00%
# Epoch [24/30], Step [400/540], Loss: 0.1438, Accuracy: 93.75%
# Epoch [24/30], Step [500/540], Loss: 0.1078, Accuracy: 96.88%
# Epoch [25/30], Step [100/540], Loss: 0.0573, Accuracy: 96.88%
# Epoch [25/30], Step [200/540], Loss: 0.0020, Accuracy: 100.00%
# Epoch [25/30], Step [300/540], Loss: 0.0020, Accuracy: 100.00%
# Epoch [25/30], Step [400/540], Loss: 0.0305, Accuracy: 100.00%
# Epoch [25/30], Step [500/540], Loss: 0.0408, Accuracy: 100.00%
# Epoch [26/30], Step [100/540], Loss: 0.0032, Accuracy: 100.00%
# Epoch [26/30], Step [200/540], Loss: 0.1289, Accuracy: 93.75%
# Epoch [26/30], Step [300/540], Loss: 0.0024, Accuracy: 100.00%
# Epoch [26/30], Step [400/540], Loss: 0.2672, Accuracy: 96.88%
# Epoch [26/30], Step [500/540], Loss: 0.0726, Accuracy: 96.88%
# Epoch [27/30], Step [100/540], Loss: 0.0926, Accuracy: 96.88%
# Epoch [27/30], Step [200/540], Loss: 0.2398, Accuracy: 93.75%
# Epoch [27/30], Step [300/540], Loss: 0.4903, Accuracy: 81.25%
# Epoch [27/30], Step [400/540], Loss: 0.0442, Accuracy: 96.88%
# Epoch [27/30], Step [500/540], Loss: 0.0067, Accuracy: 100.00%
# Epoch [28/30], Step [100/540], Loss: 0.0030, Accuracy: 100.00%
# Epoch [28/30], Step [200/540], Loss: 0.0049, Accuracy: 100.00%
# Epoch [28/30], Step [300/540], Loss: 0.0066, Accuracy: 100.00%
# Epoch [28/30], Step [400/540], Loss: 0.0011, Accuracy: 100.00%
# Epoch [28/30], Step [500/540], Loss: 0.0049, Accuracy: 100.00%
# Epoch [29/30], Step [100/540], Loss: 0.0246, Accuracy: 100.00%
# Epoch [29/30], Step [200/540], Loss: 0.0035, Accuracy: 100.00%
# Epoch [29/30], Step [300/540], Loss: 0.0309, Accuracy: 100.00%
# Epoch [29/30], Step [400/540], Loss: 0.0423, Accuracy: 96.88%
# Epoch [29/30], Step [500/540], Loss: 0.2582, Accuracy: 93.75%
# Epoch [30/30], Step [100/540], Loss: 0.0081, Accuracy: 100.00%
# Epoch [30/30], Step [200/540], Loss: 0.2986, Accuracy: 93.75%
# Epoch [30/30], Step [300/540], Loss: 0.2734, Accuracy: 96.88%
# Epoch [30/30], Step [400/540], Loss: 0.0596, Accuracy: 96.88%
# Epoch [30/30], Step [500/540], Loss: 0.1154, Accuracy: 96.88%
# ######## Training Finished in 5109.340012073517 seconds ###########

# %%
torch.save(model.state_dict(), "EuroSat-transfer-learning-resnet18-3.pt")

# %%
model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
model.load_state_dict(torch.load('EuroSat-transfer-learning-resnet18-3.pt'))
model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
model.eval() 
with torch.no_grad(): 
 correct = 0
 total = 0
 for data in data_loader_test:
  images, labels = data[0].to(device), data[1].to(device)
  labels=torch.flatten(labels)
  outputs = model(images)
  _, predicted = torch.max(outputs.data, 1)
  total += labels.size(0)
  correct += (predicted == labels).sum().item()
print('Test Accuracy of the model on the {} test images: {} %'
  .format(total, (correct / total) * 100))
# Out:
# Test Accuracy of the model on the 5400 test images: 81.11111111111111 %

# %%
acc_list = [i.item() for i in accuracies]

# %%
plt.figure()
plt.xlabel('epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy plot')
plt.plot(range(1,num_epochs+1),acc_list)
plt.legend(['Accuracy'])

# %%
plt.figure()
plt.xlabel('epochs')
plt.ylabel('Loss')
plt.title('Loss plot')
plt.plot(range(1,num_epochs+1),losses,'g')
plt.legend(['Loss'])
