# %% [markdown]
# #ALL IMPORTS

# %%
from prettytable import PrettyTable

def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
        params = parameter.numel()
        table.add_row([name, params])
        total_params+=params
    print(table)
    print(f"Total Trainable Params: {total_params}")
    return total_params

# %%
import os
import torch
import torchvision
import tarfile
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torchvision.datasets.utils import download_url
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from torch.utils.data import random_split
from torchvision.utils import make_grid
import matplotlib
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from torchvision import transforms as T, models
import glob
import torch.optim as optim
import time

import cv2
# %matplotlib inline
if torch.backends.mps.is_available() and torch.backends.mps.is_built():
    d = "mps"
elif torch.cuda.is_available():
    d = "cuda:0"
device = torch.device(d)

print("Device: {}".format(device))
# Out:
# Device: cuda:0

# %%
data_dir = 'RSI-CB256/data/'
print(os.listdir(data_dir))
# Out:
# ['cloudy', 'desert', 'green_area', 'water']

# %% [markdown]
# ## CUSTOM DATA LOADER

# %%
class CustomDataset(Dataset):
    def __init__(self,path,image_size):
        self.imgs_path = path
        file_list = glob.glob(self.imgs_path + "*")
        print(file_list)
        self.data = []
        for class_path in file_list:
            class_name = class_path.split("\\")[-1]
            for img_path in glob.glob(class_path + "/*.jpg"):
                self.data.append([img_path, class_name])
        print(self.data)
        self.class_map = {"desert" : 0, "water": 1,"green_area": 2,"cloudy": 3}
        self.img_dim = image_size
    def __len__(self):
        return len(self.data)
    def __getitem__(self, idx):
        img_path, class_name = self.data[idx]
        img = cv2.imread(img_path)
        img = cv2.resize(img, self.img_dim)
        class_id = self.class_map[class_name]
        transform = transforms.Compose([transforms.ToTensor()])
        img_tensor = transform(img)
        mean, std, var = torch.mean(img_tensor), torch.std(img_tensor), torch.var(img_tensor)
        img_tensor = (img_tensor-mean)/std
        class_id = torch.tensor([class_id])
        return img_tensor, class_id

# %% [markdown]
# ##SPLITTING DATA

# %%
from torch.utils.data.sampler import SubsetRandomSampler

def load_data(path, test_split, val_split, batch_size, input_size, shuffle_dataset=True,random_seed=42):
    dataset = CustomDataset(path,input_size)	
    # Creating data indices for training and test splits:
    dataset_size = len(dataset)
    train_test_indices = list(range(dataset_size))
    test_split = int(np.floor(test_split * dataset_size))
    if shuffle_dataset :
        np.random.seed(random_seed)
        np.random.shuffle(train_test_indices)
    train_indices, test_indices = train_test_indices[test_split:], train_test_indices[:test_split]


   # Creating data indices for training and validation splits:
   
    train_data_size=len(train_indices)
    train_val_indices = list(range(train_data_size))
    val_split = int(np.floor(val_split * train_data_size))
    if shuffle_dataset :
        np.random.seed(random_seed)
        np.random.shuffle(train_val_indices)
    train_indices, val_indices = train_val_indices[val_split:], train_val_indices[:val_split]



    # Creating PT data samplers and loaders:
    train_sampler = SubsetRandomSampler(train_indices)
    test_sampler = SubsetRandomSampler(test_indices)
    val_sampler = SubsetRandomSampler(val_indices)

    data_loader_train = torch.utils.data.DataLoader(dataset, batch_size=batch_size, 
                                              sampler=train_sampler)
    data_loader_test = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                                    sampler=test_sampler)

    data_loader_val = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                                    sampler=val_sampler)


   
    print(len(data_loader_train),len(data_loader_test),len(data_loader_val))
    
    return data_loader_train, data_loader_test, data_loader_val

# %%
data_loader_train, data_loader_test, data_loader_val=load_data(data_dir,.2,.2,32,(64,64))

print(len(data_loader_val))
# Out:
# ['RSI-CB256/data\\cloudy', 'RSI-CB256/data\\desert', 'RSI-CB256/data\\green_area', 'RSI-CB256/data\\water']
# [['RSI-CB256/data\\cloudy\\train_10021.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10043.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10070.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10081.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10096.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_101.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10128.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10166.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10173.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10177.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10201.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10224.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10225.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10231.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10263.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10265.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10269.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10293.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10326.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10333.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10389.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10406.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10421.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10451.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10485.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10493.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10538.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10540.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10547.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10552.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10555.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10563.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10566.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10581.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10598.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_1060.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10609.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10621.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10642.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10661.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10666.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10667.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10687.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_1070.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10710.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10788.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10793.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_108.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10816.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10856.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_1086.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10889.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10891.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10908.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_1092.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_10952.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_11008.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_11047.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_11050.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_11118.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_11132.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_11150.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_11161.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_11191.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_11211.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_11218.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_11240.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_11259.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_1126.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_11260.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_11283.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_11294.jpg', 'cloudy'], ['RSI-CB256/data\\cloudy\\train_11301.jpg', 'clo ...
# 113 36 29
# 29

# %% [markdown]
# ### PLOTING DATA

# %%
def plot_data_loader(data_loader, gridDims):
    
    fig, axes = plt.subplots(nrows=gridDims[0], ncols=gridDims[1], figsize=(5,5))
    dataiter = iter(data_loader)
    for i in range(gridDims[0]):
        for j in range(gridDims[1]):
            images, _ = next(dataiter)
            axes[i, j].imshow(np.transpose(images[0].numpy(), (1, 2, 0)))

# %%
plot_data_loader(data_loader_test,[2,2])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ###MODEL

# %%
#  model = models.densenet121(pretrained=False)
model = torch.hub.load('pytorch/vision:v0.10.0', 'densenet121', weights=None)
model.classifier=nn.Linear(in_features=1024, out_features=4, bias=True)
# Out:
# Using cache found in C:\Users\solan/.cache\torch\hub\pytorch_vision_v0.10.0

# %%
model.to(device)
# Out:
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Linear(in_features=1024, out_features=4, bias=True)
# )

# %% [markdown]
# ###TRAINING LOOPS

# %%
count_parameters(model)
# Out:
# +------------------------------------------------+------------+
# |                    Modules                     | Parameters |
# +------------------------------------------------+------------+
# |             features.conv0.weight              |    9408    |
# |             features.norm0.weight              |     64     |
# |              features.norm0.bias               |     64     |
# | features.denseblock1.denselayer1.norm1.weight  |     64     |
# |  features.denseblock1.denselayer1.norm1.bias   |     64     |
# | features.denseblock1.denselayer1.conv1.weight  |    8192    |
# | features.denseblock1.denselayer1.norm2.weight  |    128     |
# |  features.denseblock1.denselayer1.norm2.bias   |    128     |
# | features.denseblock1.denselayer1.conv2.weight  |   36864    |
# | features.denseblock1.denselayer2.norm1.weight  |     96     |
# |  features.denseblock1.denselayer2.norm1.bias   |     96     |
# | features.denseblock1.denselayer2.conv1.weight  |   12288    |
# | features.denseblock1.denselayer2.norm2.weight  |    128     |
# |  features.denseblock1.denselayer2.norm2.bias   |    128     |
# | features.denseblock1.denselayer2.conv2.weight  |   36864    |
# | features.denseblock1.denselayer3.norm1.weight  |    128     |
# |  features.denseblock1.denselayer3.norm1.bias   |    128     |
# | features.denseblock1.denselayer3.conv1.weight  |   16384    |
# | features.denseblock1.denselayer3.norm2.weight  |    128     |
# |  features.denseblock1.denselayer3.norm2.bias   |    128     |
# | features.denseblock1.denselayer3.conv2.weight  |   36864    |
# | features.denseblock1.denselayer4.norm1.weight  |    160     |
# |  features.denseblock1.denselayer4.norm1.bias   |    160     |
# | features.denseblock1.denselayer4.conv1.weight  |   20480    |
# | features.denseblock1.denselayer4.norm2.weight  |    128     |
# |  features.denseblock1.denselayer4.norm2.bias   |    128     |
# | features.denseblock1.denselayer4.conv2.weight  |   36864    |
# | features.denseblock1.denselayer5.norm1.weight  |    192     |
# |  features.denseblock1.denselayer5.norm1.bias   |    192     |
# | features.denseblock1.denselayer5.conv1.weight  |   24576    |
# | features.denseblock1.denselayer5.norm2.weight  |    128     |
# |  features.denseblock1.denselayer5.norm2.bias   |    128     |
# | features.denseblock1.denselayer5.conv2.weight  |   36864    |
# | features.denseblock1.denselayer6.norm1.weight  |    224     |
# |  features.denseblock1.denselayer6.norm1.bias   |    224     |
# | features.denseblock1.denselayer6.conv1.weight  |   28672    |
# | features.denseblock1.denselayer6.norm2.weight  |    128     |
# |  features.denseblock1.denselayer6.norm2.bias   |    128     |
# | features.denseblock1.denselayer6.conv2.weight  |   36864    |
# |        features.transition1.norm.weight        |    256     |
# |         features.transition1.norm.bias         |    256     |
# |        features.transition1.conv.weight        |   32768    |
# | features.denseblock2.denselayer1.norm1.weight  |    128     |
# |  features.denseblock2.denselayer1.norm1.bias   |    128     |
# | features.denseblock2.denselayer1.conv1.weight  |   16384    |
# | features.denseblock2.denselayer1.norm2.weight  |    128     |
# |  features.denseblock2.denselayer1.norm2.bias   |    128     |
# | features.denseblock2.denselayer1.conv2.weight  |   36864    |
# | features.denseblock2.denselayer2.norm1.weight  |    160     |
# |  features.denseblock2.denselayer2.norm1.bias   |    160     |
# | features.denseblock2.denselayer2.conv1.weight  |   20480    |
# | features.denseblock2.denselayer2.norm2.weight  |    128     |
# |  features.denseblock2.denselayer2.norm2.bias   |    128     |
# | features.denseblock2.denselayer2.conv2.weight  |   36864    |
# | features.denseblock2.denselayer3.norm1.weight  |    192     |
# |  features.denseblock2.denselayer3.norm1.bias   |    192     |
# | features.denseblock2.denselayer3.conv1.weight  |   24576    |
# | features.denseblock2.denselayer3.norm2.weight  |    128     |
# |  features.denseblock2.denselayer3.norm2.bias   |    128     |
# | features.denseblock2.denselayer3.conv2.weight  |   36864    |
# | features.denseblock2.denselayer4.norm1.weight  |    224     |
# |  features.denseblock2.denselayer4.norm1.bias   |    224     |
# | features.denseblock2.denselayer4.conv1.weight  |   28672    |
# | features.denseblock2.denselayer4.norm2.weight  |    128     |
# |  features.denseblock2.denselayer4.norm2.bias   |    128     |
# | features.denseblock2.denselayer4.conv2.weight  |   36864    |
# | features.denseblock2.denselayer5.norm1.weight  |    256     |
# |  features.denseblock2.denselayer5.norm1.bias   |    256     |
# | features.denseblock2.denselayer5.conv1.weight  |   32768    |
# | features.denseblock2.denselayer5.norm2.weight  |    128     |
# |  features.denseblock2.denselayer5.norm2.bias   |    128     |
# | features.denseblock2.denselayer5.conv2.weight  |   36864    |
# | features.denseblock2.denselayer6.norm1.weight  |    288     |
# |  features.denseblock2.denselayer6.norm1.bias   |    288     |
# | features.denseblock2.denselayer6.conv1.weight  |   36864    |
# | features.denseblock2.denselayer6.norm2.weight  |    128     |
# |  features.denseblock2.denselayer6.norm2.bias   |    128     |
# | features.denseblock2.denselayer6.conv2.weight  |   36864    |
# | features.denseblock2.denselayer7.norm1.weight  |    320     |
# |  features.denseblock2.denselayer7.norm1.bias   |    320     |
# | features.denseblock2.denselayer7.conv1.weight  |   40960    |
# | features.denseblock2.denselayer7.norm2.weight  |    128     |
# |  features.denseblock2.denselayer7.norm2.bias   |    128     |
# | features.denseblock2.denselayer7.conv2.weight  |   36864    |
# | features.denseblock2.denselayer8.norm1.weight  |    352     |
# |  features.denseblock2.denselayer8.norm1.bias   |    352     |
# | features.denseblock2.denselayer8.conv1.weight  |   45056    |
# | features.denseblock2.denselayer8.norm2.weight  |    128     |
# |  features.denseblock2.denselayer8.norm2.bias   |    128     |
# | features.denseblock2.denselayer8.conv2.weight  |   36864    |
# | features.denseblock2.denselayer9.norm1.weight  |    384     |
# |  features.denseblock2.denselayer9.norm1.bias   |    384     |
# | features.denseblock2.denselayer9.conv1.weight  |   49152    |
# | features.denseblock2.denselayer9.norm2.weight  |    128     |
# |  features.denseblock2.denselayer9.norm2.bias   |    128     |
# | features.denseblock2.denselayer9.conv2.weight  |   36864    |
# | features.denseblock2.denselayer10.norm1.weight |    416     |
# |  features.denseblock2.denselayer10.norm1.bias  |    416     |
# | features.denseblock2.denselayer10.conv1.weight |   53248    |
# | features.denseblock2.denselayer10.norm2.weight |    128     |
# |  features.denseblock2.denselayer10.norm2.bias  |    128     |
# | features.denseblock2.denselayer10.conv2.weight |   36864    |
# | features.denseblock2.denselayer11.norm1.weight |    448     |
# |  features.denseblock2.denselayer11.norm1.bias  |    448     |
# | features.denseblock2.denselayer11.conv1.weight |   57344    |
# | features.denseblock2.denselayer11.norm2.weight |    128     |
# |  features.denseblock2.denselayer11.norm2.bias  |    128     |
# | features.denseblock2.denselayer11.conv2.weight |   36864    |
# | features.denseblock2.denselayer12.norm1.weight |    480     |
# |  features.denseblock2.denselayer12.norm1.bias  |    480     |
# | features.denseblock2.denselayer12.conv1.weight |   61440    |
# | features.denseblock2.denselayer12.norm2.weight |    128     |
# |  features.denseblock2.denselayer12.norm2.bias  |    128     |
# | features.denseblock2.denselayer12.conv2.weight |   36864    |
# |        features.transition2.norm.weight        |    512     |
# |         features.transition2.norm.bias         |    512     |
# |        features.transition2.conv.weight        |   131072   |
# | features.denseblock3.denselayer1.norm1.weight  |    256     |
# |  features.denseblock3.denselayer1.norm1.bias   |    256     |
# | features.denseblock3.denselayer1.conv1.weight  |   32768    |
# | features.denseblock3.denselayer1.norm2.weight  |    128     |
# |  features.denseblock3.denselayer1.norm2.bias   |    128     |
# | features.denseblock3.denselayer1.conv2.weight  |   36864    |
# | features.denseblock3.denselayer2.norm1.weight  |    288     |
# |  features.denseblock3.denselayer2.norm1.bias   |    288     |
# | features.denseblock3.denselayer2.conv1.weight  |   36864    |
# | features.denseblock3.denselayer2.norm2.weight  |    128     |
# |  features.denseblock3.denselayer2.norm2.bias   |    128     |
# | features.denseblock3.denselayer2.conv2.weight  |   36864    |
# | features.denseblock3.denselayer3.norm1.weight  |    320     |
# |  features.denseblock3.denselayer3.norm1.bias   |    320     |
# | features.denseblock3.denselayer3.conv1.weight  |   40960    |
# | features.denseblock3.denselayer3.norm2.weight  |    128     |
# |  features.denseblock3.denselayer3.norm2.bias   |    128     |
# | features.denseblock3.denselayer3.conv2.weight  |   36864    |
# | features.denseblock3.denselayer4.norm1.weight  |    352     |
# |  features.denseblock3.denselayer4.norm1.bias   |    352     |
# | features.denseblock3.denselayer4.conv1.weight  |   45056    |
# | features.denseblock3.denselayer4.norm2.weight  |    128     |
# |  features.denseblock3.denselayer4.norm2.bias   |    128     |
# | features.denseblock3.denselayer4.conv2.weight  |   36864    |
# | features.denseblock3.denselayer5.norm1.weight  |    384     |
# |  features.denseblock3.denselayer5.norm1.bias   |    384     |
# | features.denseblock3.denselayer5.conv1.weight  |   49152    |
# | features.denseblock3.denselayer5.norm2.weight  |    128     |
# |  features.denseblock3.denselayer5.norm2.bias   |    128     |
# | features.denseblock3.denselayer5.conv2.weight  |   36864    |
# | features.denseblock3.denselayer6.norm1.weight  |    416     |
# |  features.denseblock3.denselayer6.norm1.bias   |    416     |
# | features.denseblock3.denselayer6.conv1.weight  |   53248    |
# | features.denseblock3.denselayer6.norm2.weight  |    128     |
# |  features.denseblock3.denselayer6.norm2.bias   |    128     |
# | features.denseblock3.denselayer6.conv2.weight  |   36864    |
# | features.denseblock3.denselayer7.norm1.weight  |    448     |
# |  features.denseblock3.denselayer7.norm1.bias   |    448     |
# | features.denseblock3.denselayer7.conv1.weight  |   57344    |
# | features.denseblock3.denselayer7.norm2.weight  |    128     |
# |  features.denseblock3.denselayer7.norm2.bias   |    128     |
# | features.denseblock3.denselayer7.conv2.weight  |   36864    |
# | features.denseblock3.denselayer8.norm1.weight  |    480     |
# |  features.denseblock3.denselayer8.norm1.bias   |    480     |
# | features.denseblock3.denselayer8.conv1.weight  |   61440    |
# | features.denseblock3.denselayer8.norm2.weight  |    128     |
# |  features.denseblock3.denselayer8.norm2.bias   |    128     |
# | features.denseblock3.denselayer8.conv2.weight  |   36864    |
# | features.denseblock3.denselayer9.norm1.weight  |    512     |
# |  features.denseblock3.denselayer9.norm1.bias   |    512     |
# | features.denseblock3.denselayer9.conv1.weight  |   65536    |
# | features.denseblock3.denselayer9.norm2.weight  |    128     |
# |  features.denseblock3.denselayer9.norm2.bias   |    128     |
# | features.denseblock3.denselayer9.conv2.weight  |   36864    |
# | features.denseblock3.denselayer10.norm1.weight |    544     |
# |  features.denseblock3.denselayer10.norm1.bias  |    544     |
# | features.denseblock3.denselayer10.conv1.weight |   69632    |
# | features.denseblock3.denselayer10.norm2.weight |    128     |
# |  features.denseblock3.denselayer10.norm2.bias  |    128     |
# | features.denseblock3.denselayer19.conv2.weight |   36864    |
# | features.denseblock3.denselayer20.norm1.weight |    864     |
# |  features.denseblock3.denselayer20.norm1.bias  |    864     |
# | features.denseblock3.denselayer20.conv1.weight |   110592   |
# | features.denseblock3.denselayer20.norm2.weight |    128     |
# |  features.denseblock3.denselayer20.norm2.bias  |    128     |
# | features.denseblock3.denselayer20.conv2.weight |   36864    |
# | features.denseblock3.denselayer21.norm1.weight |    896     |
# |  features.denseblock3.denselayer21.norm1.bias  |    896     |
# | features.denseblock3.denselayer21.conv1.weight |   114688   |
# | features.denseblock3.denselayer21.norm2.weight |    128     |
# |  features.denseblock3.denselayer21.norm2.bias  |    128     |
# | features.denseblock3.denselayer21.conv2.weight |   36864    |
# | features.denseblock3.denselayer22.norm1.weight |    928     |
# |  features.denseblock3.denselayer22.norm1.bias  |    928     |
# | features.denseblock3.denselayer22.conv1.weight |   118784   |
# | features.denseblock3.denselayer22.norm2.weight |    128     |
# |  features.denseblock3.denselayer22.norm2.bias  |    128     |
# | features.denseblock3.denselayer22.conv2.weight |   36864    |
# | features.denseblock3.denselayer23.norm1.weight |    960     |
# |  features.denseblock3.denselayer23.norm1.bias  |    960     |
# | features.denseblock3.denselayer23.conv1.weight |   122880   |
# | features.denseblock3.denselayer23.norm2.weight |    128     |
# |  features.denseblock3.denselayer23.norm2.bias  |    128     |
# | features.denseblock3.denselayer23.conv2.weight |   36864    |
# | features.denseblock3.denselayer24.norm1.weight |    992     |
# |  features.denseblock3.denselayer24.norm1.bias  |    992     |
# | features.denseblock3.denselayer24.conv1.weight |   126976   |
# | features.denseblock3.denselayer24.norm2.weight |    128     |
# |  features.denseblock3.denselayer24.norm2.bias  |    128     |
# | features.denseblock3.denselayer24.conv2.weight |   36864    |
# |        features.transition3.norm.weight        |    1024    |
# |         features.transition3.norm.bias         |    1024    |
# |        features.transition3.conv.weight        |   524288   |
# | features.denseblock4.denselayer1.norm1.weight  |    512     |
# |  features.denseblock4.denselayer1.norm1.bias   |    512     |
# | features.denseblock4.denselayer1.conv1.weight  |   65536    |
# | features.denseblock4.denselayer1.norm2.weight  |    128     |
# |  features.denseblock4.denselayer1.norm2.bias   |    128     |
# | features.denseblock4.denselayer1.conv2.weight  |   36864    |
# | features.denseblock4.denselayer2.norm1.weight  |    544     |
# |  features.denseblock4.denselayer2.norm1.bias   |    544     |
# | features.denseblock4.denselayer2.conv1.weight  |   69632    |
# | features.denseblock4.denselayer2.norm2.weight  |    128     |
# |  features.denseblock4.denselayer2.norm2.bias   |    128     |
# | features.denseblock4.denselayer2.conv2.weight  |   36864    |
# | features.denseblock4.denselayer3.norm1.weight  |    576     |
# |  features.denseblock4.denselayer3.norm1.bias   |    576     |
# | features.denseblock4.denselayer3.conv1.weight  |   73728    |
# | features.denseblock4.denselayer3.norm2.weight  |    128     |
# |  features.denseblock4.denselayer3.norm2.bias   |    128     |
# | features.denseblock4.denselayer3.conv2.weight  |   36864    |
# | features.denseblock4.denselayer4.norm1.weight  |    608     |
# |  features.denseblock4.denselayer4.norm1.bias   |    608     |
# |  features.denseblock4.denselayer13.norm1.bias  |    896     |
# | features.denseblock4.denselayer13.conv1.weight |   114688   |
# | features.denseblock4.denselayer13.norm2.weight |    128     |
# |  features.denseblock4.denselayer13.norm2.bias  |    128     |
# | features.denseblock4.denselayer13.conv2.weight |   36864    |
# | features.denseblock4.denselayer14.norm1.weight |    928     |
# |  features.denseblock4.denselayer14.norm1.bias  |    928     |
# | features.denseblock4.denselayer14.conv1.weight |   118784   |
# | features.denseblock4.denselayer14.norm2.weight |    128     |
# |  features.denseblock4.denselayer14.norm2.bias  |    128     |
# | features.denseblock4.denselayer14.conv2.weight |   36864    |
# | features.denseblock4.denselayer15.norm1.weight |    960     |
# |  features.denseblock4.denselayer15.norm1.bias  |    960     |
# | features.denseblock4.denselayer15.conv1.weight |   122880   |
# | features.denseblock4.denselayer15.norm2.weight |    128     |
# |  features.denseblock4.denselayer15.norm2.bias  |    128     |
# | features.denseblock4.denselayer15.conv2.weight |   36864    |
# | features.denseblock4.denselayer16.norm1.weight |    992     |
# |  features.denseblock4.denselayer16.norm1.bias  |    992     |
# | features.denseblock4.denselayer16.conv1.weight |   126976   |
# | features.denseblock4.denselayer16.norm2.weight |    128     |
# |  features.denseblock4.denselayer16.norm2.bias  |    128     |
# | features.denseblock4.denselayer16.conv2.weight |   36864    |
# |             features.norm5.weight              |    1024    |
# |              features.norm5.bias               |    1024    |
# |               classifier.weight                |    4096    |
# |                classifier.bias                 |     4      |
# +------------------------------------------------+------------+
# Total Trainable Params: 6957956
# 6957956

# %%
optimizer = optim.Adam(model.parameters(),lr=0.001);
criterion = nn.CrossEntropyLoss()

# %%
device
# Out:
# device(type='cuda', index=0)

# %%
num_epochs = 2
total_steps = len(data_loader_train)
t1 = time.time()
for epoch in range(num_epochs):
    for i, data in enumerate(data_loader_train):
        images, labels = data[0].to(device), data[1].to(device)
        images = data[0].to(device)
        labels=torch.flatten(labels)
        outputs = model(images)
        loss = criterion(outputs, labels)
        # Backprop and optimisation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Train accuracy
        total = labels.size(0)
        _,predicted = torch.max(outputs.data, 1)
        correct = (predicted == labels).sum().item()
        if (i + 1) % 100 == 0:
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'
                  .format(epoch + 1, num_epochs, i + 1, total_steps, loss.item(),
                      (correct / total) * 100))
           
print("######## Training Finished in {} seconds ###########".format(time.time()-t1))

# %%
# torch.save(model.state_dict(), 'Satellite-image-classification-densenet.pt')
torch.save(model, "Satellite-image-classification-densenet.pth")

# %%
# %ls

# %%
# model = models.densenet121(pretrained=False)
# model.load_state_dict(torch.load('Satellite-image-classification-densenet.pt'))

model=torch.load('Satellite-image-classification-densenet.pth')
model.eval()

# %% [markdown]
# ### MODEL EVOLUTION

# %%
model.to(device)
model.eval() 
with torch.no_grad(): 
 correct = 0
 total = 0
 for data in data_loader_test:
  images, labels = data[0].to(device), data[1].to(device)
  labels=torch.flatten(labels)
  outputs = model(images)
  _, predicted = torch.max(outputs.data, 1)
  total += labels.size(0)
  correct += (predicted == labels).sum().item()
print('Test Accuracy of the model on the {} test images: {} %'
  .format(total, (correct / total) * 100))
